# %% [markdown]
# # Intraday Strategy, Part 1: Feature Engineering

# %% [markdown]
# In this notebook, we load the high-quality NASDAQ100 minute-bar trade-and-quote data generously provided by [Algoseek](https://www.algoseek.com/) (available [here](https://www.algoseek.com/ml4t-book-data.html)) and engineer a few illustrative features.
#
# The rich set of trade and quote information contained in the Algoseek data offers various opportunities to add inforation, e.g. about relative spreads and demand/supply imbalances, but since the data is fairly large we limit our efforts to a small number of features.
#
# > Note that we will assume throughout that we can always buy (sell) at the first (last) trade price for a given bar at no cost and without market impact; this is unlikely to be true in reality but simplifies the example).
#
# The next notebook will use this dataset to train a model that predicts 1-minute returns using LightGBM.

# %% [markdown]
# ## Imports & Settings

# %%
#! sudo apt install build-essential wget -y
! wget https://artiya4u.keybase.pub/TA-lib/ta-lib-0.4.0-src.tar.gz
! tar -xvf ta-lib-0.4.0-src.tar.gz
! cd ta-lib/ && ./configure --prefix=/usr && make && sudo make install
# Out:
# --2023-02-24 11:40:51--  https://artiya4u.keybase.pub/TA-lib/ta-lib-0.4.0-src.tar.gz
# Resolving artiya4u.keybase.pub (artiya4u.keybase.pub)... 3.227.27.101, 3.95.91.171, 54.161.52.108, ...
# Connecting to artiya4u.keybase.pub (artiya4u.keybase.pub)|3.227.27.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330299 (1.3M) [application/gzip]
# Saving to: ‘ta-lib-0.4.0-src.tar.gz’
#
# ta-lib-0.4.0-src.ta 100%[===================>]   1.27M   826KB/s    in 1.6s
#
# 2023-02-24 11:41:01 (826 KB/s) - ‘ta-lib-0.4.0-src.tar.gz’ saved [1330299/1330299]
#
# ta-lib/
# ta-lib/config.sub
# ta-lib/aclocal.m4
# ta-lib/CHANGELOG.TXT
# ta-lib/include/
# ta-lib/include/ta_abstract.h
# ta-lib/include/ta_func.h
# ta-lib/include/ta_common.h
# ta-lib/include/ta_config.h.in
# ta-lib/include/Makefile.am
# ta-lib/include/ta_libc.h
# ta-lib/include/ta_defs.h
# ta-lib/missing
# ta-lib/ta-lib.spec.in
# ta-lib/config.guess
# ta-lib/Makefile.in
# ta-lib/ta-lib.dpkg.in
# ta-lib/Makefile.am
# ta-lib/autogen.sh
# ta-lib/install-sh
# ta-lib/configure
# ta-lib/depcomp
# ta-lib/HISTORY.TXT
# ta-lib/configure.in
# ta-lib/autom4te.cache/
# ta-lib/autom4te.cache/output.0
# ta-lib/autom4te.cache/requests
# ta-lib/autom4te.cache/output.1
# ta-lib/autom4te.cache/traces.0
# ta-lib/autom4te.cache/traces.1
# ta-lib/ltmain.sh
# ta-lib/ta-lib-config.in
# ta-lib/src/
# ta-lib/src/ta_func/
# ta-lib/src/ta_func/ta_MACDFIX.c
# ta-lib/src/ta_func/ta_CDLPIERCING.c
# ta-lib/src/ta_func/ta_DIV.c
# ta-lib/src/ta_func/ta_ROCR100.c
# ta-lib/src/ta_func/ta_ADXR.c
# ta-lib/src/ta_func/ta_MAVP.c
# ta-lib/src/ta_func/ta_CDLCLOSINGMARUBOZU.c
# ta-lib/src/ta_func/ta_COSH.c
# ta-lib/src/ta_func/ta_EXP.c
# ta-lib/src/ta_func/ta_MINMAXINDEX.c
# ta-lib/src/ta_func/ta_SQRT.c
# ta-lib/src/ta_func/ta_FLOOR.c
# ta-lib/src/ta_func/ta_CDLCONCEALBABYSWALL.c
# ta-lib/src/ta_func/ta_NATR.c
# ta-lib/src/ta_func/ta_CDLHARAMICROSS.c
# ta-lib/src/ta_func/ta_MINUS_DM.c
# ta-lib/src/ta_func/ta_LOG10.c
# ta-lib/src/ta_func/ta_LINEARREG_ANGLE.c
# ta-lib/src/ta_func/ta_RSI.c
# ta-lib/src/ta_func/ta_CDLABANDONEDBABY.c
# ta-lib/src/ta_func/ta_SAR.c
# ta-lib/src/ta_func/ta_CDLBREAKAWAY.c
# ta-lib/src/ta_func/ta_CDLDRAGONFLYDOJI.c
# ta-lib/src/ta_func/ta_CDLHIGHWAVE.c
# ta-lib/src/ta_func/ta_CDLKICKING.c
# ta-lib/src/ta_func/ta_CDLDOJISTAR.c
# ta-lib/src/ta_func/ta_VAR.c
# ta-lib/src/ta_func/ta_CDLMATCHINGLOW.c
# ta-lib/src/ta_func/ta_CDLGAPSIDESIDEWHITE.c
# ta-lib/src/ta_func/ta_CDLMARUBOZU.c
# ta-lib/src/ta_func/ta_AROONOSC.c
# ta-lib/src/ta_func/ta_WCLPRICE.c
# ta-lib/src/ta_func/ta_CDLEVENINGDOJISTAR.c
# ta-lib/src/ta_func/ta_CDL3INSIDE.c
# ta-lib/src/ta_func/ta_OBV.c
# ta-lib/src/ta_func/ta_AROON.c
# ta-lib/src/ta_func/ta_CDLBELTHOLD.c
# ta-lib/src/ta_func/ta_CDLSPINNINGTOP.c
# ta-lib/src/ta_func/ta_AD.c
# ta-lib/src/ta_func/ta_MAX.c
# ta-lib/src/ta_func/ta_CDLENGULFING.c
# ta-lib/src/ta_func/ta_MINMAX.c
# ta-lib/src/ta_func/ta_CDLINNECK.c
# ta-lib/src/ta_func/ta_STDDEV.c
# ta-lib/src/ta_func/ta_NVI.c
# ta-lib/src/ta_func/ta_CDLHAMMER.c
# ta-lib/src/ta_func/ta_ASIN.c
# ta-lib/src/ta_func/ta_SUM.c
# ta-lib/src/ta_func/ta_STOCH.c
# ta-lib/src/ta_func/ta_CDLLONGLEGGEDDOJI.c
# ta-lib/src/ta_func/ta_MEDPRICE.c
# ta-lib/src/ta_func/ta_CDL3STARSINSOUTH.c
# ta-lib/src/ta_func/ta_HT_TRENDMODE.c
# ta-lib/src/ta_func/ta_BBANDS.c
# ta-lib/src/ta_func/ta_CDLMORNINGSTAR.c
# ta-lib/src/ta_func/ta_HT_DCPHASE.c
# ta-lib/src/ta_func/ta_CDLLONGLINE.c
# ta-lib/src/ta_func/ta_TAN.c
# ta-lib/src/ta_func/ta_SMA.c
# ta-lib/src/ta_func/ta_DX.c
# ta-lib/src/ta_func/ta_MIDPOINT.c
# ta-lib/src/ta_func/ta_CDL2CROWS.c
# ta-lib/src/ta_func/ta_CORREL.c
# ta-lib/src/ta_func/ta_CDL3BLACKCROWS.c
# ta-lib/src/ta_func/ta_ADD.c
# ta-lib/src/ta_func/Makefile.in
# ta-lib/src/ta_func/ta_CDLTHRUSTING.c
# ta-lib/src/ta_func/ta_SUB.c
# ta-lib/src/ta_func/ta_CDLSTALLEDPATTERN.c
# ta-lib/src/ta_func/ta_CDLTRISTAR.c
# ta-lib/src/ta_func/ta_MA.c
# ta-lib/src/ta_func/ta_HT_SINE.c
# ta-lib/src/ta_func/ta_ACOS.c
# ta-lib/src/ta_func/ta_CDLSTICKSANDWICH.c
# ta-lib/src/ta_func/ta_SINH.c
# ta-lib/src/ta_func/ta_utility.h
# ta-lib/src/ta_func/ta_CDLSHORTLINE.c
# ta-lib/src/ta_func/ta_ATAN.c
# ta-lib/src/ta_func/ta_CDLADVANCEBLOCK.c
# ta-lib/src/ta_func/ta_CDLKICKINGBYLENGTH.c
# ta-lib/src/ta_func/ta_CDLSHOOTINGSTAR.c
# ta-lib/src/ta_func/ta_ROCR.c
# ta-lib/src/ta_func/ta_WMA.c
# ta-lib/src/ta_func/ta_CDLDARKCLOUDCOVER.c
# ta-lib/src/ta_func/ta_CDLXSIDEGAP3METHODS.c
# ta-lib/src/ta_func/ta_TYPPRICE.c
# ta-lib/src/ta_func/ta_CDL3WHITESOLDIERS.c
# ta-lib/src/ta_func/Makefile.am
# ta-lib/src/ta_func/ta_MACDEXT.c
# ta-lib/src/ta_func/ta_ADX.c
# ta-lib/src/ta_func/ta_PLUS_DM.c
# ta-lib/src/ta_func/ta_CDLUPSIDEGAP2CROWS.c
# ta-lib/src/ta_func/ta_LN.c
# ta-lib/src/ta_func/ta_DEMA.c
# ta-lib/src/ta_func/ta_CDL3OUTSIDE.c
# ta-lib/src/ta_func/ta_CDLTASUKIGAP.c
# ta-lib/src/ta_func/ta_MAMA.c
# ta-lib/src/ta_func/ta_CDLMORNINGDOJISTAR.c
# ta-lib/src/ta_func/ta_PLUS_DI.c
# ta-lib/src/ta_func/ta_MININDEX.c
# ta-lib/src/ta_func/ta_COS.c
# ta-lib/src/ta_func/ta_HT_TRENDLINE.c
# ta-lib/src/ta_func/ta_MIDPRICE.c
# ta-lib/src/ta_func/ta_CEIL.c
# ta-lib/src/ta_func/ta_TRIMA.c
# ta-lib/src/ta_func/ta_CDLSEPARATINGLINES.c
# ta-lib/src/ta_func/ta_ROCP.c
# ta-lib/src/ta_func/ta_CDLHOMINGPIGEON.c
# ta-lib/src/ta_func/ta_CDLHANGINGMAN.c
# ta-lib/src/ta_func/ta_AVGPRICE.c
# ta-lib/src/ta_func/ta_APO.c
# ta-lib/src/ta_func/ta_CDLRISEFALL3METHODS.c
# ta-lib/src/ta_func/ta_TRANGE.c
# ta-lib/src/ta_func/ta_TSF.c
# ta-lib/src/ta_func/ta_LINEARREG.c
# ta-lib/src/ta_func/ta_PVI.c
# ta-lib/src/ta_func/ta_CDLHIKKAKEMOD.c
# ta-lib/src/ta_func/ta_MFI.c
# ta-lib/src/ta_func/ta_CDLHARAMI.c
# ta-lib/src/ta_func/ta_MACD.c
# ta-lib/src/ta_func/ta_BETA.c
# ta-lib/src/ta_func/ta_CDLINVERTEDHAMMER.c
# ta-lib/src/ta_func/ta_LINEARREG_SLOPE.c
# ta-lib/src/ta_func/ta_STOCHF.c
# ta-lib/src/ta_func/ta_MIN.c
# ta-lib/src/ta_func/ta_CDLIDENTICAL3CROWS.c
# ta-lib/src/ta_func/ta_CDLRICKSHAWMAN.c
# ta-lib/src/ta_func/ta_T3.c
# ta-lib/src/ta_func/ta_CDLMATHOLD.c
# ta-lib/src/ta_func/ta_CDLUNIQUE3RIVER.c
# ta-lib/src/ta_func/ta_ADOSC.c
# ta-lib/src/ta_func/ta_MAXINDEX.c
# ta-lib/src/ta_func/ta_ULTOSC.c
# ta-lib/src/ta_func/ta_TRIX.c
# ta-lib/src/ta_func/ta_MOM.c
# ta-lib/src/ta_func/ta_CDLDOJI.c
# ta-lib/src/ta_func/ta_EMA.c
# ta-lib/src/ta_func/ta_STOCHRSI.c
# ta-lib/src/ta_func/ta_ROC.c
# ta-lib/src/ta_func/ta_CDLEVENINGSTAR.c
# ta-lib/src/ta_func/ta_CDLCOUNTERATTACK.c
# ta-lib/src/ta_func/ta_LINEARREG_INTERCEPT.c
# ta-lib/src/ta_func/ta_SAREXT.c
# ta-lib/src/ta_func/ta_WILLR.c
# ta-lib/src/ta_func/ta_MULT.c
# ta-lib/src/ta_func/ta_ATR.c
# ta-lib/src/ta_func/ta_BOP.c
# ta-lib/src/ta_func/ta_CMO.c
# ta-lib/src/ta_func/ta_CDLONNECK.c
# ta-lib/src/ta_func/ta_CCI.c
# ta-lib/src/ta_func/ta_CDLLADDERBOTTOM.c
# ta-lib/src/ta_func/ta_HT_PHASOR.c
# ta-lib/src/ta_func/ta_utility.c
# ta-lib/src/ta_func/ta_PPO.c
# ta-lib/src/ta_func/ta_CDLHIKKAKE.c
# ta-lib/src/ta_func/ta_HT_DCPERIOD.c
# ta-lib/src/ta_func/ta_CDL3LINESTRIKE.c
# ta-lib/src/ta_func/ta_TEMA.c
# ta-lib/src/ta_func/ta_SIN.c
# ta-lib/src/ta_func/ta_MINUS_DI.c
# ta-lib/src/ta_func/ta_KAMA.c
# ta-lib/src/ta_func/ta_TANH.c
# ta-lib/src/ta_func/ta_CDLTAKURI.c
# ta-lib/src/ta_func/ta_CDLGRAVESTONEDOJI.c
# ta-lib/src/ta_common/
# ta-lib/src/ta_common/ta_pragma.h
# ta-lib/src/ta_common/ta_magic_nb.h
# ta-lib/src/ta_common/ta_retcode.csv
# ta-lib/src/ta_common/Makefile.in
# ta-lib/src/ta_common/Makefile.am
# ta-lib/src/ta_common/ta_memory.h
# ta-lib/src/ta_common/ta_version.c
# ta-lib/src/ta_common/ta_global.h
# ta-lib/src/ta_common/ta_global.c
# ta-lib/src/ta_common/ta_retcode.c
# ta-lib/src/Makefile.in
# ta-lib/src/ta_abstract/
# ta-lib/src/ta_abstract/frames/
# ta-lib/src/ta_abstract/frames/ta_frame.c
# ta-lib/src/ta_abstract/frames/ta_frame.h
# ta-lib/src/ta_abstract/excel_glue.c
# ta-lib/src/ta_abstract/ta_frame_priv.h
# ta-lib/src/ta_abstract/ta_func_api.c
# ta-lib/src/ta_abstract/Makefile.in
# ta-lib/src/ta_abstract/ta_def_ui.h
# ta-lib/src/ta_abstract/Makefile.am
# ta-lib/src/ta_abstract/ta_abstract.c
# ta-lib/src/ta_abstract/ta_group_idx.c
# ta-lib/src/ta_abstract/tables/
# ta-lib/src/ta_abstract/tables/table_u.c
# ta-lib/src/ta_abstract/tables/table_x.c
# ta-lib/src/ta_abstract/tables/table_r.c
# ta-lib/src/ta_abstract/tables/table_f.c
# ta-lib/src/ta_abstract/tables/table_j.c
# ta-lib/src/ta_abstract/tables/table_e.c
# ta-lib/src/ta_abstract/tables/table_t.c
# ta-lib/src/ta_abstract/tables/table_n.c
# ta-lib/src/ta_abstract/tables/table_i.c
# ta-lib/src/ta_abstract/tables/table_c.c
# ta-lib/src/ta_abstract/tables/table_l.c
# ta-lib/src/ta_abstract/tables/table_k.c
# ta-lib/src/ta_abstract/tables/table_g.c
# ta-lib/src/ta_abstract/tables/table_d.c
# ta-lib/src/ta_abstract/tables/table_h.c
# ta-lib/src/ta_abstract/tables/table_o.c
# ta-lib/src/ta_abstract/tables/table_b.c
# ta-lib/src/ta_abstract/tables/table_q.c
# ta-lib/src/ta_abstract/tables/table_v.c
# ta-lib/src/ta_abstract/tables/table_m.c
# ta-lib/src/ta_abstract/tables/table_s.c
# ta-lib/src/ta_abstract/tables/table_y.c
# ta-lib/src/ta_abstract/tables/table_p.c
# ta-lib/src/ta_abstract/tables/table_z.c
# ta-lib/src/ta_abstract/tables/table_a.c
# ta-lib/src/ta_abstract/tables/table_w.c
# ta-lib/src/ta_abstract/ta_def_ui.c
# ta-lib/src/ta_abstract/templates/
# ta-lib/src/ta_abstract/templates/ta_x.c.template
# ta-lib/src/ta_abstract/templates/ta_java_defs.h.template
# ta-lib/src/ta_abstract/templates/excel_glue.c.template
# ta-lib/src/ta_abstract/templates/ta_group_idx.c.template
# ta-lib/src/ta_abstract/templates/ta_frame.c.template
# ta-lib/src/ta_abstract/templates/CoreAnnotated.java.template
# ta-lib/src/ta_abstract/templates/ta_func.h.template
# ta-lib/src/ta_abstract/templates/ta_frame.h.template
# ta-lib/src/ta_abstract/templates/Makefile.am.template
# ta-lib/src/ta_abstract/templates/ta_func_api.c.template
# ta-lib/src/ta_abstract/templates/ta_func.swg.template
# ta-lib/src/ta_abstract/templates/ta_retcode.c.template
# ta-lib/src/ta_abstract/ta_java_defs.h
# ta-lib/src/Makefile.am
# ta-lib/src/tools/
# ta-lib/src/tools/ta_regtest/
# ta-lib/src/tools/ta_regtest/test_util.c
# ta-lib/src/tools/ta_regtest/ta_test_func.h
# ta-lib/src/tools/ta_regtest/test_data.c
# ta-lib/src/tools/ta_regtest/ta_gDataHigh.c
# ta-lib/src/tools/ta_regtest/Makefile.in
# ta-lib/src/tools/ta_regtest/test_internals.c
# ta-lib/src/tools/ta_regtest/Makefile.am
# ta-lib/src/tools/ta_regtest/ta_regtest.c
# ta-lib/src/tools/ta_regtest/ta_gDataOpen.c
# ta-lib/src/tools/ta_regtest/ta_gDataClose.c
# ta-lib/src/tools/ta_regtest/test_abstract.c
# ta-lib/src/tools/ta_regtest/ta_test_func/
# ta-lib/src/tools/ta_regtest/ta_test_func/test_bbands.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stddev.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_2out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_sar.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_1out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_trange.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_macd.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_po.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_mom.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ohlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_adx.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_candlestick.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_rsi.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ema.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_minmax.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlcv.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hl.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stoch.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_ma.c
# ta-lib/src/tools/ta_regtest/ta_error_number.h
# ta-lib/src/tools/ta_regtest/ta_test_priv.h
# ta-lib/src/tools/ta_regtest/ReadMe.txt
# ta-lib/src/tools/ta_regtest/ta_gDataLow.c
# ta-lib/src/tools/Makefile.in
# ta-lib/src/tools/Makefile.am
# ta-lib/src/tools/gen_code/
# ta-lib/src/tools/gen_code/java/
# ta-lib/src/tools/gen_code/java/PrettyCode.java
# ta-lib/src/tools/gen_code/java/Main.java
# ta-lib/src/tools/gen_code/gen_code.c
# ta-lib/src/tools/gen_code/Makefile.in
# ta-lib/src/tools/gen_code/Makefile.am
# ta-lib/src/tools/gen_code/mcpp.exe
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for /usr/bin/ld option to reload object files... -r
# checking for BSD-compatible nm... /usr/bin/nm -B
# checking whether ln -s works... yes
# checking how to recognise dependent libraries... pass_all
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking dlfcn.h usability... yes
# checking dlfcn.h presence... yes
# checking for dlfcn.h... yes
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking how to run the C++ preprocessor... g++ -E
# checking for g77... no
# checking for xlf... no
# checking for f77... f77
# checking whether we are using the GNU Fortran 77 compiler... yes
# checking whether f77 accepts -g... yes
# checking the maximum length of command line arguments... 32768
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for objdir... .libs
# checking for ar... ar
# checking for ranlib... ranlib
# checking for strip... strip
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC
# checking if gcc PIC flag -fPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# configure: creating libtool
# appending configuration tag "CXX" to libtool
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC
# checking if g++ PIC flag -fPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# appending configuration tag "F77" to libtool
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking for f77 option to produce PIC... -fPIC
# checking if f77 PIC flag -fPIC works... yes
# checking if f77 static flag -static works... yes
# checking if f77 supports -c -o file.o... yes
# checking whether the f77 linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for dlopen in -ldl... yes
# checking for pthread_create in -lpthread... yes
# checking for ANSI C header files... (cached) yes
# checking float.h usability... yes
# checking float.h presence... yes
# checking for float.h... yes
# checking for inttypes.h... (cached) yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking stddef.h usability... yes
# checking stddef.h presence... yes
# checking for stddef.h... yes
# checking for stdint.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for string.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking wchar.h usability... yes
# checking wchar.h presence... yes
# checking for wchar.h... yes
# checking wctype.h usability... yes
# checking wctype.h presence... yes
# checking for wctype.h... yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking whether struct tm is in sys/time.h or time.h... time.h
# checking for working volatile... yes
# checking for ptrdiff_t... yes
# checking return type of signal handlers... void
# checking for working strcoll... yes
# checking for strftime... yes
# checking for working strtod... yes
# checking for vprintf... yes
# checking for _doprnt... no
# checking for floor... no
# checking for isascii... yes
# checking for localeconv... yes
# checking for mblen... yes
# checking for memmove... yes
# checking for memset... yes
# checking for modf... yes
# checking for pow... no
# checking for sqrt... no
# checking for strcasecmp... yes
# checking for strchr... yes
# checking for strerror... yes
# checking for strncasecmp... yes
# checking for strrchr... yes
# checking for strstr... yes
# checking for strtol... yes
# checking for strtoul... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/ta_abstract/Makefile
# config.status: creating src/ta_common/Makefile
# config.status: creating src/ta_func/Makefile
# config.status: creating src/tools/Makefile
# config.status: creating src/tools/gen_code/Makefile
# config.status: creating src/tools/ta_regtest/Makefile
# config.status: creating ta-lib-config
# config.status: creating ta-lib.spec
# config.status: creating ta-lib.dpkg
# config.status: creating include/ta_config.h
# config.status: executing depfiles commands
# Making all in src
# make[1]: Entering directory '/content/ta-lib/src'
# Making all in ta_abstract
# make[2]: Entering directory '/content/ta-lib/src/ta_abstract'
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_la-ta_group_idx.Tpo -c -o libta_abstract_la-ta_group_idx.lo `test -f 'ta_group_idx.c' || echo './'`ta_group_idx.c
# mkdir .libs
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_la-ta_group_idx.Tpo -c ta_group_idx.c  -fPIC -DPIC -o .libs/libta_abstract_la-ta_group_idx.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_la-ta_group_idx.Tpo -c ta_group_idx.c -o libta_abstract_la-ta_group_idx.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-ta_group_idx.Tpo .deps/libta_abstract_la-ta_group_idx.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-ta_def_ui.lo -MD -MP -MF .deps/libta_abstract_la-ta_def_ui.Tpo -c -o libta_abstract_la-ta_def_ui.lo `test -f 'ta_def_ui.c' || echo './'`ta_def_ui.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_def_ui.lo -MD -MP -MF .deps/libta_abstract_la-ta_def_ui.Tpo -c ta_def_ui.c  -fPIC -DPIC -o .libs/libta_abstract_la-ta_def_ui.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_def_ui.lo -MD -MP -MF .deps/libta_abstract_la-ta_def_ui.Tpo -c ta_def_ui.c -o libta_abstract_la-ta_def_ui.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-ta_def_ui.Tpo .deps/libta_abstract_la-ta_def_ui.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-ta_abstract.lo -MD -MP -MF .deps/libta_abstract_la-ta_abstract.Tpo -c -o libta_abstract_la-ta_abstract.lo `test -f 'ta_abstract.c' || echo './'`ta_abstract.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_abstract.lo -MD -MP -MF .deps/libta_abstract_la-ta_abstract.Tpo -c ta_abstract.c  -fPIC -DPIC -o .libs/libta_abstract_la-ta_abstract.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_abstract.lo -MD -MP -MF .deps/libta_abstract_la-ta_abstract.Tpo -c ta_abstract.c -o libta_abstract_la-ta_abstract.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-ta_abstract.Tpo .deps/libta_abstract_la-ta_abstract.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-ta_func_api.lo -MD -MP -MF .deps/libta_abstract_la-ta_func_api.Tpo -c -o libta_abstract_la-ta_func_api.lo `test -f 'ta_func_api.c' || echo './'`ta_func_api.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_func_api.lo -MD -MP -MF .deps/libta_abstract_la-ta_func_api.Tpo -c ta_func_api.c  -fPIC -DPIC -o .libs/libta_abstract_la-ta_func_api.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_func_api.lo -MD -MP -MF .deps/libta_abstract_la-ta_func_api.Tpo -c ta_func_api.c -o libta_abstract_la-ta_func_api.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-ta_func_api.Tpo .deps/libta_abstract_la-ta_func_api.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-ta_frame.lo -MD -MP -MF .deps/libta_abstract_la-ta_frame.Tpo -c -o libta_abstract_la-ta_frame.lo `test -f 'frames/ta_frame.c' || echo './'`frames/ta_frame.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_frame.lo -MD -MP -MF .deps/libta_abstract_la-ta_frame.Tpo -c frames/ta_frame.c  -fPIC -DPIC -o .libs/libta_abstract_la-ta_frame.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-ta_frame.lo -MD -MP -MF .deps/libta_abstract_la-ta_frame.Tpo -c frames/ta_frame.c -o libta_abstract_la-ta_frame.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-ta_frame.Tpo .deps/libta_abstract_la-ta_frame.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_a.lo -MD -MP -MF .deps/libta_abstract_la-table_a.Tpo -c -o libta_abstract_la-table_a.lo `test -f 'tables/table_a.c' || echo './'`tables/table_a.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_a.lo -MD -MP -MF .deps/libta_abstract_la-table_a.Tpo -c tables/table_a.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_a.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_a.lo -MD -MP -MF .deps/libta_abstract_la-table_a.Tpo -c tables/table_a.c -o libta_abstract_la-table_a.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_a.Tpo .deps/libta_abstract_la-table_a.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_b.lo -MD -MP -MF .deps/libta_abstract_la-table_b.Tpo -c -o libta_abstract_la-table_b.lo `test -f 'tables/table_b.c' || echo './'`tables/table_b.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_b.lo -MD -MP -MF .deps/libta_abstract_la-table_b.Tpo -c tables/table_b.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_b.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_b.lo -MD -MP -MF .deps/libta_abstract_la-table_b.Tpo -c tables/table_b.c -o libta_abstract_la-table_b.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_b.Tpo .deps/libta_abstract_la-table_b.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_c.lo -MD -MP -MF .deps/libta_abstract_la-table_c.Tpo -c -o libta_abstract_la-table_c.lo `test -f 'tables/table_c.c' || echo './'`tables/table_c.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_c.lo -MD -MP -MF .deps/libta_abstract_la-table_c.Tpo -c tables/table_c.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_c.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_c.lo -MD -MP -MF .deps/libta_abstract_la-table_c.Tpo -c tables/table_c.c -o libta_abstract_la-table_c.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_c.Tpo .deps/libta_abstract_la-table_c.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_d.lo -MD -MP -MF .deps/libta_abstract_la-table_d.Tpo -c -o libta_abstract_la-table_d.lo `test -f 'tables/table_d.c' || echo './'`tables/table_d.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_d.lo -MD -MP -MF .deps/libta_abstract_la-table_d.Tpo -c tables/table_d.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_d.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_d.lo -MD -MP -MF .deps/libta_abstract_la-table_d.Tpo -c tables/table_d.c -o libta_abstract_la-table_d.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_d.Tpo .deps/libta_abstract_la-table_d.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_e.lo -MD -MP -MF .deps/libta_abstract_la-table_e.Tpo -c -o libta_abstract_la-table_e.lo `test -f 'tables/table_e.c' || echo './'`tables/table_e.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_e.lo -MD -MP -MF .deps/libta_abstract_la-table_e.Tpo -c tables/table_e.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_e.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_e.lo -MD -MP -MF .deps/libta_abstract_la-table_e.Tpo -c tables/table_e.c -o libta_abstract_la-table_e.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_e.Tpo .deps/libta_abstract_la-table_e.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_f.lo -MD -MP -MF .deps/libta_abstract_la-table_f.Tpo -c -o libta_abstract_la-table_f.lo `test -f 'tables/table_f.c' || echo './'`tables/table_f.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_f.lo -MD -MP -MF .deps/libta_abstract_la-table_f.Tpo -c tables/table_f.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_f.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_f.lo -MD -MP -MF .deps/libta_abstract_la-table_f.Tpo -c tables/table_f.c -o libta_abstract_la-table_f.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_f.Tpo .deps/libta_abstract_la-table_f.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_g.lo -MD -MP -MF .deps/libta_abstract_la-table_g.Tpo -c -o libta_abstract_la-table_g.lo `test -f 'tables/table_g.c' || echo './'`tables/table_g.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_g.lo -MD -MP -MF .deps/libta_abstract_la-table_g.Tpo -c tables/table_g.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_g.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_g.lo -MD -MP -MF .deps/libta_abstract_la-table_g.Tpo -c tables/table_g.c -o libta_abstract_la-table_g.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_g.Tpo .deps/libta_abstract_la-table_g.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_h.lo -MD -MP -MF .deps/libta_abstract_la-table_h.Tpo -c -o libta_abstract_la-table_h.lo `test -f 'tables/table_h.c' || echo './'`tables/table_h.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_h.lo -MD -MP -MF .deps/libta_abstract_la-table_h.Tpo -c tables/table_h.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_h.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_h.lo -MD -MP -MF .deps/libta_abstract_la-table_h.Tpo -c tables/table_h.c -o libta_abstract_la-table_h.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_h.Tpo .deps/libta_abstract_la-table_h.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_i.lo -MD -MP -MF .deps/libta_abstract_la-table_i.Tpo -c -o libta_abstract_la-table_i.lo `test -f 'tables/table_i.c' || echo './'`tables/table_i.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_i.lo -MD -MP -MF .deps/libta_abstract_la-table_i.Tpo -c tables/table_i.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_i.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_i.lo -MD -MP -MF .deps/libta_abstract_la-table_i.Tpo -c tables/table_i.c -o libta_abstract_la-table_i.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_i.Tpo .deps/libta_abstract_la-table_i.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_j.lo -MD -MP -MF .deps/libta_abstract_la-table_j.Tpo -c -o libta_abstract_la-table_j.lo `test -f 'tables/table_j.c' || echo './'`tables/table_j.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_j.lo -MD -MP -MF .deps/libta_abstract_la-table_j.Tpo -c tables/table_j.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_j.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_j.lo -MD -MP -MF .deps/libta_abstract_la-table_j.Tpo -c tables/table_j.c -o libta_abstract_la-table_j.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_j.Tpo .deps/libta_abstract_la-table_j.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_k.lo -MD -MP -MF .deps/libta_abstract_la-table_k.Tpo -c -o libta_abstract_la-table_k.lo `test -f 'tables/table_k.c' || echo './'`tables/table_k.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_k.lo -MD -MP -MF .deps/libta_abstract_la-table_k.Tpo -c tables/table_k.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_k.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_k.lo -MD -MP -MF .deps/libta_abstract_la-table_k.Tpo -c tables/table_k.c -o libta_abstract_la-table_k.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_k.Tpo .deps/libta_abstract_la-table_k.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_l.lo -MD -MP -MF .deps/libta_abstract_la-table_l.Tpo -c -o libta_abstract_la-table_l.lo `test -f 'tables/table_l.c' || echo './'`tables/table_l.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_l.lo -MD -MP -MF .deps/libta_abstract_la-table_l.Tpo -c tables/table_l.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_l.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_l.lo -MD -MP -MF .deps/libta_abstract_la-table_l.Tpo -c tables/table_l.c -o libta_abstract_la-table_l.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_l.Tpo .deps/libta_abstract_la-table_l.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_m.lo -MD -MP -MF .deps/libta_abstract_la-table_m.Tpo -c -o libta_abstract_la-table_m.lo `test -f 'tables/table_m.c' || echo './'`tables/table_m.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_m.lo -MD -MP -MF .deps/libta_abstract_la-table_m.Tpo -c tables/table_m.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_m.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_m.lo -MD -MP -MF .deps/libta_abstract_la-table_m.Tpo -c tables/table_m.c -o libta_abstract_la-table_m.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_m.Tpo .deps/libta_abstract_la-table_m.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_n.lo -MD -MP -MF .deps/libta_abstract_la-table_n.Tpo -c -o libta_abstract_la-table_n.lo `test -f 'tables/table_n.c' || echo './'`tables/table_n.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_n.lo -MD -MP -MF .deps/libta_abstract_la-table_n.Tpo -c tables/table_n.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_n.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_n.lo -MD -MP -MF .deps/libta_abstract_la-table_n.Tpo -c tables/table_n.c -o libta_abstract_la-table_n.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_n.Tpo .deps/libta_abstract_la-table_n.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_o.lo -MD -MP -MF .deps/libta_abstract_la-table_o.Tpo -c -o libta_abstract_la-table_o.lo `test -f 'tables/table_o.c' || echo './'`tables/table_o.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_o.lo -MD -MP -MF .deps/libta_abstract_la-table_o.Tpo -c tables/table_o.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_o.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_o.lo -MD -MP -MF .deps/libta_abstract_la-table_o.Tpo -c tables/table_o.c -o libta_abstract_la-table_o.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_o.Tpo .deps/libta_abstract_la-table_o.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_p.lo -MD -MP -MF .deps/libta_abstract_la-table_p.Tpo -c -o libta_abstract_la-table_p.lo `test -f 'tables/table_p.c' || echo './'`tables/table_p.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_p.lo -MD -MP -MF .deps/libta_abstract_la-table_p.Tpo -c tables/table_p.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_p.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_p.lo -MD -MP -MF .deps/libta_abstract_la-table_p.Tpo -c tables/table_p.c -o libta_abstract_la-table_p.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_p.Tpo .deps/libta_abstract_la-table_p.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_q.lo -MD -MP -MF .deps/libta_abstract_la-table_q.Tpo -c -o libta_abstract_la-table_q.lo `test -f 'tables/table_q.c' || echo './'`tables/table_q.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_q.lo -MD -MP -MF .deps/libta_abstract_la-table_q.Tpo -c tables/table_q.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_q.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_q.lo -MD -MP -MF .deps/libta_abstract_la-table_q.Tpo -c tables/table_q.c -o libta_abstract_la-table_q.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_q.Tpo .deps/libta_abstract_la-table_q.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_r.lo -MD -MP -MF .deps/libta_abstract_la-table_r.Tpo -c -o libta_abstract_la-table_r.lo `test -f 'tables/table_r.c' || echo './'`tables/table_r.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_r.lo -MD -MP -MF .deps/libta_abstract_la-table_r.Tpo -c tables/table_r.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_r.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_r.lo -MD -MP -MF .deps/libta_abstract_la-table_r.Tpo -c tables/table_r.c -o libta_abstract_la-table_r.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_r.Tpo .deps/libta_abstract_la-table_r.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_s.lo -MD -MP -MF .deps/libta_abstract_la-table_s.Tpo -c -o libta_abstract_la-table_s.lo `test -f 'tables/table_s.c' || echo './'`tables/table_s.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_s.lo -MD -MP -MF .deps/libta_abstract_la-table_s.Tpo -c tables/table_s.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_s.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_s.lo -MD -MP -MF .deps/libta_abstract_la-table_s.Tpo -c tables/table_s.c -o libta_abstract_la-table_s.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_s.Tpo .deps/libta_abstract_la-table_s.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_t.lo -MD -MP -MF .deps/libta_abstract_la-table_t.Tpo -c -o libta_abstract_la-table_t.lo `test -f 'tables/table_t.c' || echo './'`tables/table_t.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_t.lo -MD -MP -MF .deps/libta_abstract_la-table_t.Tpo -c tables/table_t.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_t.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_t.lo -MD -MP -MF .deps/libta_abstract_la-table_t.Tpo -c tables/table_t.c -o libta_abstract_la-table_t.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_t.Tpo .deps/libta_abstract_la-table_t.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_u.lo -MD -MP -MF .deps/libta_abstract_la-table_u.Tpo -c -o libta_abstract_la-table_u.lo `test -f 'tables/table_u.c' || echo './'`tables/table_u.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_u.lo -MD -MP -MF .deps/libta_abstract_la-table_u.Tpo -c tables/table_u.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_u.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_u.lo -MD -MP -MF .deps/libta_abstract_la-table_u.Tpo -c tables/table_u.c -o libta_abstract_la-table_u.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_u.Tpo .deps/libta_abstract_la-table_u.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_v.lo -MD -MP -MF .deps/libta_abstract_la-table_v.Tpo -c -o libta_abstract_la-table_v.lo `test -f 'tables/table_v.c' || echo './'`tables/table_v.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_v.lo -MD -MP -MF .deps/libta_abstract_la-table_v.Tpo -c tables/table_v.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_v.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_v.lo -MD -MP -MF .deps/libta_abstract_la-table_v.Tpo -c tables/table_v.c -o libta_abstract_la-table_v.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_v.Tpo .deps/libta_abstract_la-table_v.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_w.lo -MD -MP -MF .deps/libta_abstract_la-table_w.Tpo -c -o libta_abstract_la-table_w.lo `test -f 'tables/table_w.c' || echo './'`tables/table_w.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_w.lo -MD -MP -MF .deps/libta_abstract_la-table_w.Tpo -c tables/table_w.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_w.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_w.lo -MD -MP -MF .deps/libta_abstract_la-table_w.Tpo -c tables/table_w.c -o libta_abstract_la-table_w.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_w.Tpo .deps/libta_abstract_la-table_w.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_x.lo -MD -MP -MF .deps/libta_abstract_la-table_x.Tpo -c -o libta_abstract_la-table_x.lo `test -f 'tables/table_x.c' || echo './'`tables/table_x.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_x.lo -MD -MP -MF .deps/libta_abstract_la-table_x.Tpo -c tables/table_x.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_x.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_x.lo -MD -MP -MF .deps/libta_abstract_la-table_x.Tpo -c tables/table_x.c -o libta_abstract_la-table_x.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_x.Tpo .deps/libta_abstract_la-table_x.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_y.lo -MD -MP -MF .deps/libta_abstract_la-table_y.Tpo -c -o libta_abstract_la-table_y.lo `test -f 'tables/table_y.c' || echo './'`tables/table_y.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_y.lo -MD -MP -MF .deps/libta_abstract_la-table_y.Tpo -c tables/table_y.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_y.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_y.lo -MD -MP -MF .deps/libta_abstract_la-table_y.Tpo -c tables/table_y.c -o libta_abstract_la-table_y.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_y.Tpo .deps/libta_abstract_la-table_y.Plo
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_la-table_z.lo -MD -MP -MF .deps/libta_abstract_la-table_z.Tpo -c -o libta_abstract_la-table_z.lo `test -f 'tables/table_z.c' || echo './'`tables/table_z.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_z.lo -MD -MP -MF .deps/libta_abstract_la-table_z.Tpo -c tables/table_z.c  -fPIC -DPIC -o .libs/libta_abstract_la-table_z.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_la-table_z.lo -MD -MP -MF .deps/libta_abstract_la-table_z.Tpo -c tables/table_z.c -o libta_abstract_la-table_z.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_la-table_z.Tpo .deps/libta_abstract_la-table_z.Plo
# /bin/bash ../../libtool --tag=CC   --mode=link gcc  -g -O2 -version-info 0:0:0  -o libta_abstract.la  libta_abstract_la-ta_group_idx.lo libta_abstract_la-ta_def_ui.lo libta_abstract_la-ta_abstract.lo libta_abstract_la-ta_func_api.lo libta_abstract_la-ta_frame.lo libta_abstract_la-table_a.lo libta_abstract_la-table_b.lo libta_abstract_la-table_c.lo libta_abstract_la-table_d.lo libta_abstract_la-table_e.lo libta_abstract_la-table_f.lo libta_abstract_la-table_g.lo libta_abstract_la-table_h.lo libta_abstract_la-table_i.lo libta_abstract_la-table_j.lo libta_abstract_la-table_k.lo libta_abstract_la-table_l.lo libta_abstract_la-table_m.lo libta_abstract_la-table_n.lo libta_abstract_la-table_o.lo libta_abstract_la-table_p.lo libta_abstract_la-table_q.lo libta_abstract_la-table_r.lo libta_abstract_la-table_s.lo libta_abstract_la-table_t.lo libta_abstract_la-table_u.lo libta_abstract_la-table_v.lo libta_abstract_la-table_w.lo libta_abstract_la-table_x.lo libta_abstract_la-table_y.lo libta_abstract_la-table_z.lo  -lpthread -ldl
# libtool: link: warning: `-version-info/-version-number' is ignored for convenience libraries
# ar cru .libs/libta_abstract.a .libs/libta_abstract_la-ta_group_idx.o .libs/libta_abstract_la-ta_def_ui.o .libs/libta_abstract_la-ta_abstract.o .libs/libta_abstract_la-ta_func_api.o .libs/libta_abstract_la-ta_frame.o .libs/libta_abstract_la-table_a.o .libs/libta_abstract_la-table_b.o .libs/libta_abstract_la-table_c.o .libs/libta_abstract_la-table_d.o .libs/libta_abstract_la-table_e.o .libs/libta_abstract_la-table_f.o .libs/libta_abstract_la-table_g.o .libs/libta_abstract_la-table_h.o .libs/libta_abstract_la-table_i.o .libs/libta_abstract_la-table_j.o .libs/libta_abstract_la-table_k.o .libs/libta_abstract_la-table_l.o .libs/libta_abstract_la-table_m.o .libs/libta_abstract_la-table_n.o .libs/libta_abstract_la-table_o.o .libs/libta_abstract_la-table_p.o .libs/libta_abstract_la-table_q.o .libs/libta_abstract_la-table_r.o .libs/libta_abstract_la-table_s.o .libs/libta_abstract_la-table_t.o .libs/libta_abstract_la-table_u.o .libs/libta_abstract_la-table_v.o .libs/libta_abstract_la-table_w.o .libs/libta_abstract_la-table_x.o .libs/libta_abstract_la-table_y.o .libs/libta_abstract_la-table_z.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# ranlib .libs/libta_abstract.a
# creating libta_abstract.la
# (cd .libs && rm -f libta_abstract.la && ln -s ../libta_abstract.la libta_abstract.la)
# /bin/bash ../../libtool --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../../include  -DTA_GEN_CODE -I../ta_common/ -Iframes/   -g -O2 -MT libta_abstract_gc_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_gc_la-ta_group_idx.Tpo -c -o libta_abstract_gc_la-ta_group_idx.lo `test -f 'ta_group_idx.c' || echo './'`ta_group_idx.c
#  gcc -DHAVE_CONFIG_H -I. -I../../include -DTA_GEN_CODE -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_gc_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_gc_la-ta_group_idx.Tpo -c ta_group_idx.c  -fPIC -DPIC -o .libs/libta_abstract_gc_la-ta_group_idx.o
#  gcc -DHAVE_CONFIG_H -I. -I../../include -DTA_GEN_CODE -I../ta_common/ -Iframes/ -g -O2 -MT libta_abstract_gc_la-ta_group_idx.lo -MD -MP -MF .deps/libta_abstract_gc_la-ta_group_idx.Tpo -c ta_group_idx.c -o libta_abstract_gc_la-ta_group_idx.o >/dev/null 2>&1
# mv -f .deps/libta_abstract_gc_la-ta_group_idx.Tpo .deps/libta_abstract_gc_la-ta_group_idx.Plo
# ...
# mv -f .deps/ta_regtest-test_adx.Tpo .deps/ta_regtest-test_adx.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_mom.o -MD -MP -MF .deps/ta_regtest-test_mom.Tpo -c -o ta_regtest-test_mom.o `test -f 'ta_test_func/test_mom.c' || echo './'`ta_test_func/test_mom.c
# mv -f .deps/ta_regtest-test_mom.Tpo .deps/ta_regtest-test_mom.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_sar.o -MD -MP -MF .deps/ta_regtest-test_sar.Tpo -c -o ta_regtest-test_sar.o `test -f 'ta_test_func/test_sar.c' || echo './'`ta_test_func/test_sar.c
# mv -f .deps/ta_regtest-test_sar.Tpo .deps/ta_regtest-test_sar.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_rsi.o -MD -MP -MF .deps/ta_regtest-test_rsi.Tpo -c -o ta_regtest-test_rsi.o `test -f 'ta_test_func/test_rsi.c' || echo './'`ta_test_func/test_rsi.c
# mv -f .deps/ta_regtest-test_rsi.Tpo .deps/ta_regtest-test_rsi.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_candlestick.o -MD -MP -MF .deps/ta_regtest-test_candlestick.Tpo -c -o ta_regtest-test_candlestick.o `test -f 'ta_test_func/test_candlestick.c' || echo './'`ta_test_func/test_candlestick.c
# mv -f .deps/ta_regtest-test_candlestick.Tpo .deps/ta_regtest-test_candlestick.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_per_ema.o -MD -MP -MF .deps/ta_regtest-test_per_ema.Tpo -c -o ta_regtest-test_per_ema.o `test -f 'ta_test_func/test_per_ema.c' || echo './'`ta_test_func/test_per_ema.c
# mv -f .deps/ta_regtest-test_per_ema.Tpo .deps/ta_regtest-test_per_ema.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_per_hlc.o -MD -MP -MF .deps/ta_regtest-test_per_hlc.Tpo -c -o ta_regtest-test_per_hlc.o `test -f 'ta_test_func/test_per_hlc.c' || echo './'`ta_test_func/test_per_hlc.c
# mv -f .deps/ta_regtest-test_per_hlc.Tpo .deps/ta_regtest-test_per_hlc.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_stoch.o -MD -MP -MF .deps/ta_regtest-test_stoch.Tpo -c -o ta_regtest-test_stoch.o `test -f 'ta_test_func/test_stoch.c' || echo './'`ta_test_func/test_stoch.c
# mv -f .deps/ta_regtest-test_stoch.Tpo .deps/ta_regtest-test_stoch.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_macd.o -MD -MP -MF .deps/ta_regtest-test_macd.Tpo -c -o ta_regtest-test_macd.o `test -f 'ta_test_func/test_macd.c' || echo './'`ta_test_func/test_macd.c
# mv -f .deps/ta_regtest-test_macd.Tpo .deps/ta_regtest-test_macd.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_minmax.o -MD -MP -MF .deps/ta_regtest-test_minmax.Tpo -c -o ta_regtest-test_minmax.o `test -f 'ta_test_func/test_minmax.c' || echo './'`ta_test_func/test_minmax.c
# mv -f .deps/ta_regtest-test_minmax.Tpo .deps/ta_regtest-test_minmax.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_per_hlcv.o -MD -MP -MF .deps/ta_regtest-test_per_hlcv.Tpo -c -o ta_regtest-test_per_hlcv.o `test -f 'ta_test_func/test_per_hlcv.c' || echo './'`ta_test_func/test_per_hlcv.c
# mv -f .deps/ta_regtest-test_per_hlcv.Tpo .deps/ta_regtest-test_per_hlcv.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_1in_1out.o -MD -MP -MF .deps/ta_regtest-test_1in_1out.Tpo -c -o ta_regtest-test_1in_1out.o `test -f 'ta_test_func/test_1in_1out.c' || echo './'`ta_test_func/test_1in_1out.c
# mv -f .deps/ta_regtest-test_1in_1out.Tpo .deps/ta_regtest-test_1in_1out.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_1in_2out.o -MD -MP -MF .deps/ta_regtest-test_1in_2out.Tpo -c -o ta_regtest-test_1in_2out.o `test -f 'ta_test_func/test_1in_2out.c' || echo './'`ta_test_func/test_1in_2out.c
# mv -f .deps/ta_regtest-test_1in_2out.Tpo .deps/ta_regtest-test_1in_2out.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_per_ohlc.o -MD -MP -MF .deps/ta_regtest-test_per_ohlc.Tpo -c -o ta_regtest-test_per_ohlc.o `test -f 'ta_test_func/test_per_ohlc.c' || echo './'`ta_test_func/test_per_ohlc.c
# mv -f .deps/ta_regtest-test_per_ohlc.Tpo .deps/ta_regtest-test_per_ohlc.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_stddev.o -MD -MP -MF .deps/ta_regtest-test_stddev.Tpo -c -o ta_regtest-test_stddev.o `test -f 'ta_test_func/test_stddev.c' || echo './'`ta_test_func/test_stddev.c
# mv -f .deps/ta_regtest-test_stddev.Tpo .deps/ta_regtest-test_stddev.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_bbands.o -MD -MP -MF .deps/ta_regtest-test_bbands.Tpo -c -o ta_regtest-test_bbands.o `test -f 'ta_test_func/test_bbands.c' || echo './'`ta_test_func/test_bbands.c
# mv -f .deps/ta_regtest-test_bbands.Tpo .deps/ta_regtest-test_bbands.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_ma.o -MD -MP -MF .deps/ta_regtest-test_ma.Tpo -c -o ta_regtest-test_ma.o `test -f 'ta_test_func/test_ma.c' || echo './'`ta_test_func/test_ma.c
# mv -f .deps/ta_regtest-test_ma.Tpo .deps/ta_regtest-test_ma.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_po.o -MD -MP -MF .deps/ta_regtest-test_po.Tpo -c -o ta_regtest-test_po.o `test -f 'ta_test_func/test_po.c' || echo './'`ta_test_func/test_po.c
# mv -f .deps/ta_regtest-test_po.Tpo .deps/ta_regtest-test_po.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_per_hl.o -MD -MP -MF .deps/ta_regtest-test_per_hl.Tpo -c -o ta_regtest-test_per_hl.o `test -f 'ta_test_func/test_per_hl.c' || echo './'`ta_test_func/test_per_hl.c
# mv -f .deps/ta_regtest-test_per_hl.Tpo .deps/ta_regtest-test_per_hl.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_trange.o -MD -MP -MF .deps/ta_regtest-test_trange.Tpo -c -o ta_regtest-test_trange.o `test -f 'ta_test_func/test_trange.c' || echo './'`ta_test_func/test_trange.c
# mv -f .deps/ta_regtest-test_trange.Tpo .deps/ta_regtest-test_trange.Po
# gcc -DHAVE_CONFIG_H -I. -I../../../include  -I../../ta_func -I../../ta_common/trio -I../../ta_common/mt -I../../ta_common -I../../ta_abstract   -g -O2 -MT ta_regtest-test_internals.o -MD -MP -MF .deps/ta_regtest-test_internals.Tpo -c -o ta_regtest-test_internals.o `test -f 'test_internals.c' || echo './'`test_internals.c
# mv -f .deps/ta_regtest-test_internals.Tpo .deps/ta_regtest-test_internals.Po
# /bin/bash ../../../libtool --tag=CC   --mode=link gcc  -g -O2 -L../.. -lta_lib -lm  -o ta_regtest ta_regtest-ta_regtest.o ta_regtest-test_data.o ta_regtest-test_util.o ta_regtest-test_abstract.o ta_regtest-test_adx.o ta_regtest-test_mom.o ta_regtest-test_sar.o ta_regtest-test_rsi.o ta_regtest-test_candlestick.o ta_regtest-test_per_ema.o ta_regtest-test_per_hlc.o ta_regtest-test_stoch.o ta_regtest-test_macd.o ta_regtest-test_minmax.o ta_regtest-test_per_hlcv.o ta_regtest-test_1in_1out.o ta_regtest-test_1in_2out.o ta_regtest-test_per_ohlc.o ta_regtest-test_stddev.o ta_regtest-test_bbands.o ta_regtest-test_ma.o ta_regtest-test_po.o ta_regtest-test_per_hl.o ta_regtest-test_trange.o ta_regtest-test_internals.o  -lpthread -ldl
# mkdir .libs
# gcc -g -O2 -o .libs/ta_regtest ta_regtest-ta_regtest.o ta_regtest-test_data.o ta_regtest-test_util.o ta_regtest-test_abstract.o ta_regtest-test_adx.o ta_regtest-test_mom.o ta_regtest-test_sar.o ta_regtest-test_rsi.o ta_regtest-test_candlestick.o ta_regtest-test_per_ema.o ta_regtest-test_per_hlc.o ta_regtest-test_stoch.o ta_regtest-test_macd.o ta_regtest-test_minmax.o ta_regtest-test_per_hlcv.o ta_regtest-test_1in_1out.o ta_regtest-test_1in_2out.o ta_regtest-test_per_ohlc.o ta_regtest-test_stddev.o ta_regtest-test_bbands.o ta_regtest-test_ma.o ta_regtest-test_po.o ta_regtest-test_per_hl.o ta_regtest-test_trange.o ta_regtest-test_internals.o  -L/content/ta-lib/src /content/ta-lib/src/.libs/libta_lib.so -lm -lpthread -ldl
# creating ta_regtest
# make[2]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Entering directory '/content/ta-lib/src/tools'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Entering directory '/content/ta-lib'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/content/ta-lib'
# Making install in src
# make[1]: Entering directory '/content/ta-lib/src'
# Making install in ta_abstract
# make[2]: Entering directory '/content/ta-lib/src/ta_abstract'
# make[3]: Entering directory '/content/ta-lib/src/ta_abstract'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_abstract.h' '/usr/include/ta-lib//ta_abstract.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_abstract'
# make[2]: Leaving directory '/content/ta-lib/src/ta_abstract'
# Making install in ta_common
# make[2]: Entering directory '/content/ta-lib/src/ta_common'
# make[3]: Entering directory '/content/ta-lib/src/ta_common'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_common.h' '/usr/include/ta-lib//ta_common.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_common'
# make[2]: Leaving directory '/content/ta-lib/src/ta_common'
# Making install in ta_func
# make[2]: Entering directory '/content/ta-lib/src/ta_func'
# make[3]: Entering directory '/content/ta-lib/src/ta_func'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
#  /usr/bin/install -c -m 644 '../../include/ta_defs.h' '/usr/include/ta-lib//ta_defs.h'
#  /usr/bin/install -c -m 644 '../../include/ta_libc.h' '/usr/include/ta-lib//ta_libc.h'
#  /usr/bin/install -c -m 644 '../../include/ta_func.h' '/usr/include/ta-lib//ta_func.h'
# make[3]: Leaving directory '/content/ta-lib/src/ta_func'
# make[2]: Leaving directory '/content/ta-lib/src/ta_func'
# make[2]: Entering directory '/content/ta-lib/src'
# make[3]: Entering directory '/content/ta-lib/src'
# test -z "/usr/lib" || /usr/bin/mkdir -p "/usr/lib"
#  /bin/bash ../libtool --mode=install /usr/bin/install -c  'libta_lib.la' '/usr/lib/libta_lib.la'
# /usr/bin/install -c .libs/libta_lib.so.0.0.0 /usr/lib/libta_lib.so.0.0.0
# (cd /usr/lib && { ln -s -f libta_lib.so.0.0.0 libta_lib.so.0 || { rm -f libta_lib.so.0 && ln -s libta_lib.so.0.0.0 libta_lib.so.0; }; })
# (cd /usr/lib && { ln -s -f libta_lib.so.0.0.0 libta_lib.so || { rm -f libta_lib.so && ln -s libta_lib.so.0.0.0 libta_lib.so; }; })
# /usr/bin/install -c .libs/libta_lib.lai /usr/lib/libta_lib.la
# /usr/bin/install -c .libs/libta_lib.a /usr/lib/libta_lib.a
# chmod 644 /usr/lib/libta_lib.a
# ranlib /usr/lib/libta_lib.a
# PATH="$PATH:/sbin" ldconfig -n /usr/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,--rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src'
# make[2]: Leaving directory '/content/ta-lib/src'
# make[1]: Leaving directory '/content/ta-lib/src'
# Making install in src/tools
# make[1]: Entering directory '/content/ta-lib/src/tools'
# Making install in gen_code
# make[2]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make  gen_code
# make[3]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make[3]: 'gen_code' is up to date.
# make[3]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# cp gen_code ../../../bin
# make[3]: Entering directory '/content/ta-lib/src/tools/gen_code'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# make[2]: Leaving directory '/content/ta-lib/src/tools/gen_code'
# Making install in ta_regtest
# make[2]: Entering directory '/content/ta-lib/src/tools/ta_regtest'
# make[3]: Entering directory '/content/ta-lib/src/tools/ta_regtest'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Leaving directory '/content/ta-lib/src/tools/ta_regtest'
# make[2]: Entering directory '/content/ta-lib/src/tools'
# make[3]: Entering directory '/content/ta-lib/src/tools'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/ta-lib/src/tools'
# make[2]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Leaving directory '/content/ta-lib/src/tools'
# make[1]: Entering directory '/content/ta-lib'
# make[2]: Entering directory '/content/ta-lib'
# test -z "/usr/bin" || /usr/bin/mkdir -p "/usr/bin"
#  /usr/bin/install -c 'ta-lib-config' '/usr/bin/ta-lib-config'
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/content/ta-lib'
# make[1]: Leaving directory '/content/ta-lib'

# %%
! sudo pip install TA-Lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting TA-Lib
#   Downloading TA-Lib-0.4.25.tar.gz (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from TA-Lib) (1.22.4)
# Building wheels for collected packages: TA-Lib
#   Building wheel for TA-Lib (pyproject.toml) ... done
#   Created wheel for TA-Lib: filename=TA_Lib-0.4.25-cp38-cp38-linux_x86_64.whl size=2510053 sha256=75380f225736849df1a7e1d0a42ba8e9ffd37345437a56018e0f19c469b50d24
#   Stored in directory: /root/.cache/pip/wheels/da/72/bf/464831127ee8d6d9a5b76340a6a2f115182e159309dc3067ca
# Successfully built TA-Lib
# Installing collected packages: TA-Lib
# Successfully installed TA-Lib-0.4.25

# %%
# !wget https://algoseek-public.s3.amazonaws.com/nasdaq100-1min.zip
! unzip nasdaq100-1min.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: nasdaq100/2015/20150910/KHC.csv.gz
#   inflating: nasdaq100/2015/20150910/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150910/JD.csv.gz
#   inflating: nasdaq100/2015/20150910/INTU.csv.gz
#   inflating: nasdaq100/2015/20150910/INTC.csv.gz
#   inflating: nasdaq100/2015/20150910/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150910/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150910/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150910/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150910/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150910/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150910/GILD.csv.gz
#   inflating: nasdaq100/2015/20150910/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150910/FOX.csv.gz
#   inflating: nasdaq100/2015/20150910/FB.csv.gz
#   inflating: nasdaq100/2015/20150910/FISV.csv.gz
#   inflating: nasdaq100/2015/20150910/FAST.csv.gz
#   inflating: nasdaq100/2015/20150910/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150910/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150910/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150910/EA.csv.gz
#   inflating: nasdaq100/2015/20150910/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150910/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150910/DISH.csv.gz
#   inflating: nasdaq100/2015/20150910/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150910/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150910/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150910/COST.csv.gz
#   inflating: nasdaq100/2015/20150910/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150910/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150910/CELG.csv.gz
#   inflating: nasdaq100/2015/20150910/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150910/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150910/CERN.csv.gz
#   inflating: nasdaq100/2015/20150910/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150910/CA.csv.gz
#   inflating: nasdaq100/2015/20150910/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150910/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150910/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150910/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150910/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150910/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150910/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150910/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150910/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150910/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150910/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150910/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150910/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150910/ADI.csv.gz
#   inflating: nasdaq100/2015/20150910/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150910/ADP.csv.gz
#   inflating: nasdaq100/2015/20150910/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150910/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150910/AAL.csv.gz
#    creating: nasdaq100/2015/20150909/
#   inflating: nasdaq100/2015/20150909/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150909/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150909/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150909/WFM.csv.gz
#   inflating: nasdaq100/2015/20150909/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150909/WDC.csv.gz
#   inflating: nasdaq100/2015/20150909/WBA.csv.gz
#   inflating: nasdaq100/2015/20150909/VOD.csv.gz
#   inflating: nasdaq100/2015/20150909/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150909/VIP.csv.gz
#   inflating: nasdaq100/2015/20150909/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150909/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150909/TXN.csv.gz
#   inflating: nasdaq100/2015/20150909/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150909/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150909/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150909/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150909/STX.csv.gz
#   inflating: nasdaq100/2015/20150909/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150909/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150909/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150909/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150909/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150909/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150909/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150909/ROST.csv.gz
#   inflating: nasdaq100/2015/20150909/REGN.csv.gz
#   inflating: nasdaq100/2015/20150909/MAT.csv.gz
#   inflating: nasdaq100/2015/20150909/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150909/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150909/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150909/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150909/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150909/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150909/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150909/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150909/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150909/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150909/MYL.csv.gz
#   inflating: nasdaq100/2015/20150909/MU.csv.gz
#   inflating: nasdaq100/2015/20150909/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150909/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150909/MNST.csv.gz
#   inflating: nasdaq100/2015/20150909/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150909/MAR.csv.gz
#   inflating: nasdaq100/2015/20150909/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150909/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150909/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150909/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150909/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150909/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150909/LILA.csv.gz
#   inflating: nasdaq100/2015/20150909/INTC.csv.gz
#   inflating: nasdaq100/2015/20150909/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150909/KHC.csv.gz
#   inflating: nasdaq100/2015/20150909/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150909/JD.csv.gz
#   inflating: nasdaq100/2015/20150909/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150909/INTU.csv.gz
#   inflating: nasdaq100/2015/20150909/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150909/FB.csv.gz
#   inflating: nasdaq100/2015/20150909/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150909/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150909/GILD.csv.gz
#   inflating: nasdaq100/2015/20150909/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150909/FISV.csv.gz
#   inflating: nasdaq100/2015/20150909/FOX.csv.gz
#   inflating: nasdaq100/2015/20150909/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150909/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150909/FAST.csv.gz
#   inflating: nasdaq100/2015/20150909/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150909/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150909/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150909/EA.csv.gz
#   inflating: nasdaq100/2015/20150909/DISH.csv.gz
#   inflating: nasdaq100/2015/20150909/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150909/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150909/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150909/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150909/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150909/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150909/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150909/COST.csv.gz
#   inflating: nasdaq100/2015/20150909/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150909/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150909/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150909/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150909/CERN.csv.gz
#   inflating: nasdaq100/2015/20150909/CA.csv.gz
#   inflating: nasdaq100/2015/20150909/CELG.csv.gz
#   inflating: nasdaq100/2015/20150909/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150909/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150909/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150909/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150909/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150909/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150909/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150909/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150909/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150909/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150909/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150909/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150909/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150909/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150909/ADP.csv.gz
#   inflating: nasdaq100/2015/20150909/ADI.csv.gz
#   inflating: nasdaq100/2015/20150909/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150909/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150909/AAL.csv.gz
#    creating: nasdaq100/2015/20150908/
#   inflating: nasdaq100/2015/20150908/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150908/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150908/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150908/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150908/WFM.csv.gz
#   inflating: nasdaq100/2015/20150908/WDC.csv.gz
#   inflating: nasdaq100/2015/20150908/TXN.csv.gz
#   inflating: nasdaq100/2015/20150908/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150908/WBA.csv.gz
#   inflating: nasdaq100/2015/20150908/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150908/VOD.csv.gz
#   inflating: nasdaq100/2015/20150908/VIP.csv.gz
#   inflating: nasdaq100/2015/20150908/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150908/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150908/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150908/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150908/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150908/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150908/STX.csv.gz
#   inflating: nasdaq100/2015/20150908/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150908/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150908/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150908/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150908/ROST.csv.gz
#   inflating: nasdaq100/2015/20150908/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150908/REGN.csv.gz
#   inflating: nasdaq100/2015/20150908/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150908/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150908/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150908/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150908/MU.csv.gz
#   inflating: nasdaq100/2015/20150908/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150908/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150908/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150908/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150908/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150908/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150908/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150908/MYL.csv.gz
#   inflating: nasdaq100/2015/20150908/MNST.csv.gz
#   inflating: nasdaq100/2015/20150908/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150908/MAT.csv.gz
#   inflating: nasdaq100/2015/20150908/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150908/MAR.csv.gz
#   inflating: nasdaq100/2015/20150908/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150908/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150908/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150908/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150908/LILA.csv.gz
#   inflating: nasdaq100/2015/20150908/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150908/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150908/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150908/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150908/KHC.csv.gz
#   inflating: nasdaq100/2015/20150908/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150908/JD.csv.gz
#   inflating: nasdaq100/2015/20150908/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150908/INTU.csv.gz
#   inflating: nasdaq100/2015/20150908/INTC.csv.gz
#   inflating: nasdaq100/2015/20150908/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150908/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150908/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150908/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150908/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150908/GILD.csv.gz
#   inflating: nasdaq100/2015/20150908/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150908/FOX.csv.gz
#   inflating: nasdaq100/2015/20150908/FB.csv.gz
#   inflating: nasdaq100/2015/20150908/FISV.csv.gz
#   inflating: nasdaq100/2015/20150908/FAST.csv.gz
#   inflating: nasdaq100/2015/20150908/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150908/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150908/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150908/EA.csv.gz
#   inflating: nasdaq100/2015/20150908/DISH.csv.gz
#   inflating: nasdaq100/2015/20150908/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150908/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150908/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150908/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150908/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150908/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150908/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150908/COST.csv.gz
#   inflating: nasdaq100/2015/20150908/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150908/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150908/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150908/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150908/CERN.csv.gz
#   inflating: nasdaq100/2015/20150908/CELG.csv.gz
#   inflating: nasdaq100/2015/20150908/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150908/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150908/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150908/CA.csv.gz
#   inflating: nasdaq100/2015/20150908/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150908/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150908/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150908/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150908/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150908/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150908/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150908/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150908/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150908/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150908/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150908/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150908/ADI.csv.gz
#   inflating: nasdaq100/2015/20150908/ADP.csv.gz
#   inflating: nasdaq100/2015/20150908/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150908/AAL.csv.gz
#    creating: nasdaq100/2015/20150904/
#   inflating: nasdaq100/2015/20150904/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150904/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150904/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150904/WFM.csv.gz
#   inflating: nasdaq100/2015/20150904/WDC.csv.gz
#   inflating: nasdaq100/2015/20150904/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150904/WBA.csv.gz
#   inflating: nasdaq100/2015/20150904/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150904/VOD.csv.gz
#   inflating: nasdaq100/2015/20150904/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150904/VIP.csv.gz
#   inflating: nasdaq100/2015/20150904/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150904/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150904/TXN.csv.gz
#   inflating: nasdaq100/2015/20150904/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150904/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150904/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150904/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150904/STX.csv.gz
#   inflating: nasdaq100/2015/20150904/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150904/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150904/REGN.csv.gz
#   inflating: nasdaq100/2015/20150904/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150904/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150904/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150904/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150904/ROST.csv.gz
#   inflating: nasdaq100/2015/20150904/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150904/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150904/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150904/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150904/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150904/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150904/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150904/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150904/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150904/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150904/MYL.csv.gz
#   inflating: nasdaq100/2015/20150904/MU.csv.gz
#   inflating: nasdaq100/2015/20150904/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150904/MNST.csv.gz
#   inflating: nasdaq100/2015/20150904/MAT.csv.gz
#   inflating: nasdaq100/2015/20150904/MAR.csv.gz
#   inflating: nasdaq100/2015/20150904/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150904/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150904/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150904/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150904/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150904/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150904/INTC.csv.gz
#   inflating: nasdaq100/2015/20150904/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150904/LILA.csv.gz
#   inflating: nasdaq100/2015/20150904/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150904/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150904/KHC.csv.gz
#   inflating: nasdaq100/2015/20150904/JD.csv.gz
#   inflating: nasdaq100/2015/20150904/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150904/INTU.csv.gz
#   inflating: nasdaq100/2015/20150904/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150904/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150904/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150904/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150904/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150904/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150904/GILD.csv.gz
#   inflating: nasdaq100/2015/20150904/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150904/FB.csv.gz
#   inflating: nasdaq100/2015/20150904/FISV.csv.gz
#   inflating: nasdaq100/2015/20150904/FOX.csv.gz
#   inflating: nasdaq100/2015/20150904/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150904/FAST.csv.gz
#   inflating: nasdaq100/2015/20150904/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150904/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150904/EA.csv.gz
#   inflating: nasdaq100/2015/20150904/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150904/DISH.csv.gz
#   inflating: nasdaq100/2015/20150904/CELG.csv.gz
#   inflating: nasdaq100/2015/20150904/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150904/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150904/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150904/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150904/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150904/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150904/COST.csv.gz
#   inflating: nasdaq100/2015/20150904/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150904/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150904/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150904/CERN.csv.gz
#   inflating: nasdaq100/2015/20150904/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150904/CA.csv.gz
#   inflating: nasdaq100/2015/20150904/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150904/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150904/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150904/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150904/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150904/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150904/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150904/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150904/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150904/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150904/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150904/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150904/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150904/AAL.csv.gz
#   inflating: nasdaq100/2015/20150904/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150904/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150904/ADI.csv.gz
#   inflating: nasdaq100/2015/20150904/ADP.csv.gz
#   inflating: nasdaq100/2015/20150904/ADBE.csv.gz
#    creating: nasdaq100/2015/20150903/
#   inflating: nasdaq100/2015/20150903/VOD.csv.gz
#   inflating: nasdaq100/2015/20150903/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150903/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150903/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150903/WDC.csv.gz
#   inflating: nasdaq100/2015/20150903/WFM.csv.gz
#   inflating: nasdaq100/2015/20150903/WBA.csv.gz
#   inflating: nasdaq100/2015/20150903/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150903/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150903/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150903/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150903/VIP.csv.gz
#   inflating: nasdaq100/2015/20150903/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150903/STX.csv.gz
#   inflating: nasdaq100/2015/20150903/TXN.csv.gz
#   inflating: nasdaq100/2015/20150903/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150903/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150903/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150903/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150903/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150903/MAR.csv.gz
#   inflating: nasdaq100/2015/20150903/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150903/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150903/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150903/ROST.csv.gz
#   inflating: nasdaq100/2015/20150903/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150903/REGN.csv.gz
#   inflating: nasdaq100/2015/20150903/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150903/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150903/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150903/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150903/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150903/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150903/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150903/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150903/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150903/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150903/MYL.csv.gz
#   inflating: nasdaq100/2015/20150903/MU.csv.gz
#   inflating: nasdaq100/2015/20150903/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150903/MNST.csv.gz
#   inflating: nasdaq100/2015/20150903/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150903/MAT.csv.gz
#   inflating: nasdaq100/2015/20150903/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150903/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150903/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150903/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150903/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150903/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150903/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150903/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150903/LILA.csv.gz
#   inflating: nasdaq100/2015/20150903/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150903/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150903/JD.csv.gz
#   inflating: nasdaq100/2015/20150903/KHC.csv.gz
#   inflating: nasdaq100/2015/20150903/INTU.csv.gz
#   inflating: nasdaq100/2015/20150903/GILD.csv.gz
#   inflating: nasdaq100/2015/20150903/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150903/INTC.csv.gz
#   inflating: nasdaq100/2015/20150903/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150903/FB.csv.gz
#   inflating: nasdaq100/2015/20150903/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150903/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150903/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150903/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150903/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150903/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150903/FOX.csv.gz
#   inflating: nasdaq100/2015/20150903/FISV.csv.gz
#   inflating: nasdaq100/2015/20150903/FAST.csv.gz
#   inflating: nasdaq100/2015/20150903/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150903/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150903/EA.csv.gz
#   inflating: nasdaq100/2015/20150903/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150903/DISH.csv.gz
#   inflating: nasdaq100/2015/20150903/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150903/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150903/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150903/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150903/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150903/COST.csv.gz
#   inflating: nasdaq100/2015/20150903/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150903/CERN.csv.gz
#   inflating: nasdaq100/2015/20150903/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150903/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150903/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150903/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150903/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150903/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150903/CELG.csv.gz
#   inflating: nasdaq100/2015/20150903/CA.csv.gz
#   inflating: nasdaq100/2015/20150903/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150903/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150903/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150903/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150903/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150903/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150903/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150903/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150903/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150903/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150903/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150903/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150903/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150903/ADI.csv.gz
#   inflating: nasdaq100/2015/20150903/ADP.csv.gz
#   inflating: nasdaq100/2015/20150903/AAL.csv.gz
#   inflating: nasdaq100/2015/20150903/ADBE.csv.gz
#    creating: nasdaq100/2015/20150902/
#   inflating: nasdaq100/2015/20150902/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150902/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150902/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150902/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150902/VOD.csv.gz
#   inflating: nasdaq100/2015/20150902/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150902/WDC.csv.gz
#   inflating: nasdaq100/2015/20150902/WBA.csv.gz
#   inflating: nasdaq100/2015/20150902/WFM.csv.gz
#   inflating: nasdaq100/2015/20150902/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150902/TXN.csv.gz
#   inflating: nasdaq100/2015/20150902/VIP.csv.gz
#   inflating: nasdaq100/2015/20150902/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150902/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150902/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150902/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150902/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150902/STX.csv.gz
#   inflating: nasdaq100/2015/20150902/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150902/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150902/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150902/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150902/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150902/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150902/ROST.csv.gz
#   inflating: nasdaq100/2015/20150902/REGN.csv.gz
#   inflating: nasdaq100/2015/20150902/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150902/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150902/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150902/MU.csv.gz
#   inflating: nasdaq100/2015/20150902/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150902/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150902/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150902/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150902/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150902/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150902/MYL.csv.gz
#   inflating: nasdaq100/2015/20150902/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150902/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150902/MNST.csv.gz
#   inflating: nasdaq100/2015/20150902/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150902/MAT.csv.gz
#   inflating: nasdaq100/2015/20150902/MAR.csv.gz
#   inflating: nasdaq100/2015/20150902/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150902/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150902/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150902/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150902/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150902/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150902/LILA.csv.gz
#   inflating: nasdaq100/2015/20150902/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150902/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150902/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150902/KHC.csv.gz
#   inflating: nasdaq100/2015/20150902/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150902/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150902/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150902/JD.csv.gz
#   inflating: nasdaq100/2015/20150902/INTU.csv.gz
#   inflating: nasdaq100/2015/20150902/INTC.csv.gz
#   inflating: nasdaq100/2015/20150902/FB.csv.gz
#   inflating: nasdaq100/2015/20150902/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150902/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150902/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150902/GILD.csv.gz
#   inflating: nasdaq100/2015/20150902/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150902/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150902/FOX.csv.gz
#   inflating: nasdaq100/2015/20150902/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150902/FAST.csv.gz
#   inflating: nasdaq100/2015/20150902/FISV.csv.gz
#   inflating: nasdaq100/2015/20150902/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150902/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150902/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150902/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150902/EA.csv.gz
#   inflating: nasdaq100/2015/20150902/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150902/DISH.csv.gz
#   inflating: nasdaq100/2015/20150902/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150902/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150902/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150902/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150902/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150902/COST.csv.gz
#   inflating: nasdaq100/2015/20150902/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150902/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150902/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150902/CELG.csv.gz
#   inflating: nasdaq100/2015/20150902/CERN.csv.gz
#   inflating: nasdaq100/2015/20150902/CA.csv.gz
#   inflating: nasdaq100/2015/20150902/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150902/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150902/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150902/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150902/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150902/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150902/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150902/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150902/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150902/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150902/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150902/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150902/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150902/ADI.csv.gz
#   inflating: nasdaq100/2015/20150902/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150902/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150902/ADP.csv.gz
#   inflating: nasdaq100/2015/20150902/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150902/AAL.csv.gz
#    creating: nasdaq100/2015/20150901/
#   inflating: nasdaq100/2015/20150901/REGN.csv.gz
#   inflating: nasdaq100/2015/20150901/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150901/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150901/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150901/WFM.csv.gz
#   inflating: nasdaq100/2015/20150901/WDC.csv.gz
#   inflating: nasdaq100/2015/20150901/MU.csv.gz
#   inflating: nasdaq100/2015/20150901/WBA.csv.gz
#   inflating: nasdaq100/2015/20150901/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150901/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150901/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150901/VOD.csv.gz
#   inflating: nasdaq100/2015/20150901/VIP.csv.gz
#   inflating: nasdaq100/2015/20150901/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150901/TXN.csv.gz
#   inflating: nasdaq100/2015/20150901/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150901/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150901/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150901/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150901/STX.csv.gz
#   inflating: nasdaq100/2015/20150901/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150901/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150901/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150901/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150901/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150901/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150901/ROST.csv.gz
#   inflating: nasdaq100/2015/20150901/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150901/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150901/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150901/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150901/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150901/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150901/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150901/MNST.csv.gz
#   inflating: nasdaq100/2015/20150901/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150901/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150901/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150901/MYL.csv.gz
#   inflating: nasdaq100/2015/20150901/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150901/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150901/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150901/MAR.csv.gz
#   inflating: nasdaq100/2015/20150901/MAT.csv.gz
#   inflating: nasdaq100/2015/20150901/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150901/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150901/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150901/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150901/KHC.csv.gz
#   inflating: nasdaq100/2015/20150901/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150901/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150901/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150901/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150901/LILA.csv.gz
#   inflating: nasdaq100/2015/20150901/JD.csv.gz
#   inflating: nasdaq100/2015/20150901/INTU.csv.gz
#   inflating: nasdaq100/2015/20150901/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150901/INTC.csv.gz
#   inflating: nasdaq100/2015/20150901/GILD.csv.gz
#   inflating: nasdaq100/2015/20150901/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150901/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150901/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150901/FB.csv.gz
#   inflating: nasdaq100/2015/20150901/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150901/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150901/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150901/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150901/FISV.csv.gz
#   inflating: nasdaq100/2015/20150901/FOX.csv.gz
#   inflating: nasdaq100/2015/20150901/FAST.csv.gz
#   inflating: nasdaq100/2015/20150901/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150901/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150901/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150901/EA.csv.gz
#   inflating: nasdaq100/2015/20150901/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150901/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150901/DISH.csv.gz
#   inflating: nasdaq100/2015/20150901/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150901/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150901/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150901/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150901/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150901/COST.csv.gz
#   inflating: nasdaq100/2015/20150901/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150901/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150901/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150901/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150901/CERN.csv.gz
#   inflating: nasdaq100/2015/20150901/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150901/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150901/CELG.csv.gz
#   inflating: nasdaq100/2015/20150901/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150901/CA.csv.gz
#   inflating: nasdaq100/2015/20150901/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150901/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150901/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150901/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150901/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150901/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150901/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150901/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150901/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150901/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150901/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150901/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150901/ADP.csv.gz
#   inflating: nasdaq100/2015/20150901/ADI.csv.gz
#   inflating: nasdaq100/2015/20150901/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150901/AAL.csv.gz
#    creating: nasdaq100/2015/20150831/
#   inflating: nasdaq100/2015/20150831/WFM.csv.gz
#   inflating: nasdaq100/2015/20150831/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150831/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150831/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150831/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150831/WBA.csv.gz
#   inflating: nasdaq100/2015/20150831/WDC.csv.gz
#   inflating: nasdaq100/2015/20150831/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150831/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150831/VOD.csv.gz
#   inflating: nasdaq100/2015/20150831/VIP.csv.gz
#   inflating: nasdaq100/2015/20150831/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150831/TXN.csv.gz
#   inflating: nasdaq100/2015/20150831/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150831/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150831/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150831/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150831/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150831/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150831/STX.csv.gz
#   inflating: nasdaq100/2015/20150831/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150831/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150831/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150831/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150831/ROST.csv.gz
#   inflating: nasdaq100/2015/20150831/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150831/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150831/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150831/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150831/MU.csv.gz
#   inflating: nasdaq100/2015/20150831/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150831/REGN.csv.gz
#   inflating: nasdaq100/2015/20150831/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150831/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150831/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150831/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150831/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150831/MYL.csv.gz
#   inflating: nasdaq100/2015/20150831/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150831/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150831/MNST.csv.gz
#   inflating: nasdaq100/2015/20150831/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150831/MAR.csv.gz
#   inflating: nasdaq100/2015/20150831/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150831/MAT.csv.gz
#   inflating: nasdaq100/2015/20150831/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150831/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150831/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150831/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150831/LILA.csv.gz
#   inflating: nasdaq100/2015/20150831/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150831/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150831/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150831/KHC.csv.gz
#   inflating: nasdaq100/2015/20150831/JD.csv.gz
#   inflating: nasdaq100/2015/20150831/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150831/CELG.csv.gz
#   inflating: nasdaq100/2015/20150831/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150831/INTU.csv.gz
#   inflating: nasdaq100/2015/20150831/INTC.csv.gz
#   inflating: nasdaq100/2015/20150831/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150831/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150831/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150831/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150831/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150831/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150831/GILD.csv.gz
#   inflating: nasdaq100/2015/20150831/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150831/FOX.csv.gz
#   inflating: nasdaq100/2015/20150831/EA.csv.gz
#   inflating: nasdaq100/2015/20150831/FB.csv.gz
#   inflating: nasdaq100/2015/20150831/FISV.csv.gz
#   inflating: nasdaq100/2015/20150831/FAST.csv.gz
#   inflating: nasdaq100/2015/20150831/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150831/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150831/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150831/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150831/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150831/DISH.csv.gz
#   inflating: nasdaq100/2015/20150831/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150831/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150831/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150831/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150831/COST.csv.gz
#   inflating: nasdaq100/2015/20150831/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150831/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150831/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150831/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150831/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150831/CERN.csv.gz
#   inflating: nasdaq100/2015/20150831/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150831/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150831/CA.csv.gz
#   inflating: nasdaq100/2015/20150831/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150831/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150831/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150831/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150831/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150831/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150831/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150831/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150831/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150831/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150831/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150831/AAL.csv.gz
#   inflating: nasdaq100/2015/20150831/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150831/ADP.csv.gz
#   inflating: nasdaq100/2015/20150831/ADI.csv.gz
#   inflating: nasdaq100/2015/20150831/ADBE.csv.gz
#    creating: nasdaq100/2015/20150828/
#   inflating: nasdaq100/2015/20150828/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150828/VOD.csv.gz
#   inflating: nasdaq100/2015/20150828/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150828/WFM.csv.gz
#   inflating: nasdaq100/2015/20150828/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150828/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150828/WDC.csv.gz
#   inflating: nasdaq100/2015/20150828/WBA.csv.gz
#   inflating: nasdaq100/2015/20150828/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150828/VIP.csv.gz
#   inflating: nasdaq100/2015/20150828/STX.csv.gz
#   inflating: nasdaq100/2015/20150828/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150828/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150828/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150828/TXN.csv.gz
#   inflating: nasdaq100/2015/20150828/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150828/SWKS.csv.gz
#   inflating: nasdaq100/2015/20150828/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150828/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150828/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150828/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150828/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150828/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150828/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150828/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150828/ROST.csv.gz
#   inflating: nasdaq100/2015/20150828/REGN.csv.gz
#   inflating: nasdaq100/2015/20150828/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150828/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150828/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150828/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150828/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150828/MYL.csv.gz
#   inflating: nasdaq100/2015/20150828/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150828/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150828/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150828/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150828/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150828/MU.csv.gz
#   inflating: nasdaq100/2015/20150828/MNST.csv.gz
#   inflating: nasdaq100/2015/20150828/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150828/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150828/MAR.csv.gz
#   inflating: nasdaq100/2015/20150828/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150828/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150828/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150828/MAT.csv.gz
#   inflating: nasdaq100/2015/20150828/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150828/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150828/LILA.csv.gz
#   inflating: nasdaq100/2015/20150828/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150828/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150828/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150828/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150828/KHC.csv.gz
#   inflating: nasdaq100/2015/20150828/JD.csv.gz
#   inflating: nasdaq100/2015/20150828/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150828/INTU.csv.gz
#   inflating: nasdaq100/2015/20150828/INTC.csv.gz
#   inflating: nasdaq100/2015/20150828/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150828/FISV.csv.gz
#   inflating: nasdaq100/2015/20150828/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150828/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150828/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150828/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150828/GILD.csv.gz
#   inflating: nasdaq100/2015/20150828/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150828/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150828/FOX.csv.gz
#   inflating: nasdaq100/2015/20150828/FB.csv.gz
#   inflating: nasdaq100/2015/20150828/FAST.csv.gz
#   inflating: nasdaq100/2015/20150828/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150828/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150828/EA.csv.gz
#   inflating: nasdaq100/2015/20150828/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150828/DISH.csv.gz
#   inflating: nasdaq100/2015/20150828/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150828/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150828/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150828/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150828/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150828/CELG.csv.gz
#   inflating: nasdaq100/2015/20150828/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150828/COST.csv.gz
#   inflating: nasdaq100/2015/20150828/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150828/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150828/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150828/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150828/CERN.csv.gz
#   inflating: nasdaq100/2015/20150828/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150828/CA.csv.gz
#   inflating: nasdaq100/2015/20150828/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150828/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150828/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150828/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150828/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150828/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150828/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150828/BMRN.csv.gz
#   inflating: nasdaq100/2015/20150828/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150828/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150828/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150828/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150828/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150828/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150828/ADP.csv.gz
#   inflating: nasdaq100/2015/20150828/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150828/ADI.csv.gz
#   inflating: nasdaq100/2015/20150828/AAL.csv.gz
#    creating: nasdaq100/2015/20150827/
#   inflating: nasdaq100/2015/20150827/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150827/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150827/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150827/WFM.csv.gz
#   inflating: nasdaq100/2015/20150827/WDC.csv.gz
#   inflating: nasdaq100/2015/20150827/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150827/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150827/WBA.csv.gz
#   inflating: nasdaq100/2015/20150827/VOD.csv.gz
# ...
#   inflating: nasdaq100/2015/20150710/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150710/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150710/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150710/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150710/STX.csv.gz
#   inflating: nasdaq100/2015/20150710/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150710/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150710/SIAL.csv.gz
#   inflating: nasdaq100/2015/20150710/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150710/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150710/ROST.csv.gz
#   inflating: nasdaq100/2015/20150710/REGN.csv.gz
#   inflating: nasdaq100/2015/20150710/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150710/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150710/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150710/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150710/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150710/MYL.csv.gz
#   inflating: nasdaq100/2015/20150710/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150710/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150710/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150710/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150710/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150710/MU.csv.gz
#   inflating: nasdaq100/2015/20150710/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150710/MNST.csv.gz
#   inflating: nasdaq100/2015/20150710/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150710/MAR.csv.gz
#   inflating: nasdaq100/2015/20150710/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150710/MAT.csv.gz
#   inflating: nasdaq100/2015/20150710/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150710/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150710/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150710/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150710/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150710/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150710/LILA.csv.gz
#   inflating: nasdaq100/2015/20150710/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150710/KHC.csv.gz
#   inflating: nasdaq100/2015/20150710/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150710/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150710/INTC.csv.gz
#   inflating: nasdaq100/2015/20150710/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150710/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150710/INTU.csv.gz
#   inflating: nasdaq100/2015/20150710/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150710/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150710/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150710/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150710/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150710/GILD.csv.gz
#   inflating: nasdaq100/2015/20150710/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150710/FISV.csv.gz
#   inflating: nasdaq100/2015/20150710/FB.csv.gz
#   inflating: nasdaq100/2015/20150710/FOX.csv.gz
#   inflating: nasdaq100/2015/20150710/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150710/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150710/FAST.csv.gz
#   inflating: nasdaq100/2015/20150710/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150710/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150710/EA.csv.gz
#   inflating: nasdaq100/2015/20150710/DTV.csv.gz
#   inflating: nasdaq100/2015/20150710/DISH.csv.gz
#   inflating: nasdaq100/2015/20150710/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150710/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150710/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150710/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150710/CTRX.csv.gz
#   inflating: nasdaq100/2015/20150710/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150710/COST.csv.gz
#   inflating: nasdaq100/2015/20150710/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150710/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150710/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150710/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150710/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150710/CERN.csv.gz
#   inflating: nasdaq100/2015/20150710/CA.csv.gz
#   inflating: nasdaq100/2015/20150710/CELG.csv.gz
#   inflating: nasdaq100/2015/20150710/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150710/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150710/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150710/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150710/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150710/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150710/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150710/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150710/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150710/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150710/ADP.csv.gz
#   inflating: nasdaq100/2015/20150710/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150710/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150710/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150710/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150710/ADI.csv.gz
#   inflating: nasdaq100/2015/20150710/AAL.csv.gz
#    creating: nasdaq100/2015/20150709/
#   inflating: nasdaq100/2015/20150709/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150709/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150709/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150709/WFM.csv.gz
#   inflating: nasdaq100/2015/20150709/WDC.csv.gz
#   inflating: nasdaq100/2015/20150709/WBA.csv.gz
#   inflating: nasdaq100/2015/20150709/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150709/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150709/VIP.csv.gz
#   inflating: nasdaq100/2015/20150709/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150709/VOD.csv.gz
#   inflating: nasdaq100/2015/20150709/TXN.csv.gz
#   inflating: nasdaq100/2015/20150709/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150709/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150709/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150709/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150709/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150709/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150709/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150709/STX.csv.gz
#   inflating: nasdaq100/2015/20150709/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150709/SIAL.csv.gz
#   inflating: nasdaq100/2015/20150709/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150709/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150709/ROST.csv.gz
#   inflating: nasdaq100/2015/20150709/REGN.csv.gz
#   inflating: nasdaq100/2015/20150709/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150709/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150709/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150709/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150709/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150709/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150709/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150709/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150709/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150709/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150709/MYL.csv.gz
#   inflating: nasdaq100/2015/20150709/MU.csv.gz
#   inflating: nasdaq100/2015/20150709/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150709/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150709/MNST.csv.gz
#   inflating: nasdaq100/2015/20150709/MAT.csv.gz
#   inflating: nasdaq100/2015/20150709/MAR.csv.gz
#   inflating: nasdaq100/2015/20150709/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150709/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150709/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150709/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150709/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150709/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150709/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150709/LILA.csv.gz
#   inflating: nasdaq100/2015/20150709/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150709/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150709/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150709/KHC.csv.gz
#   inflating: nasdaq100/2015/20150709/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150709/INTU.csv.gz
#   inflating: nasdaq100/2015/20150709/INTC.csv.gz
#   inflating: nasdaq100/2015/20150709/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150709/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150709/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150709/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150709/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150709/GILD.csv.gz
#   inflating: nasdaq100/2015/20150709/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150709/FISV.csv.gz
#   inflating: nasdaq100/2015/20150709/FOX.csv.gz
#   inflating: nasdaq100/2015/20150709/FAST.csv.gz
#   inflating: nasdaq100/2015/20150709/FB.csv.gz
#   inflating: nasdaq100/2015/20150709/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150709/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150709/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150709/EA.csv.gz
#   inflating: nasdaq100/2015/20150709/DTV.csv.gz
#   inflating: nasdaq100/2015/20150709/DISH.csv.gz
#   inflating: nasdaq100/2015/20150709/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150709/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150709/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150709/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150709/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150709/CTRX.csv.gz
#   inflating: nasdaq100/2015/20150709/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150709/COST.csv.gz
#   inflating: nasdaq100/2015/20150709/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150709/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150709/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150709/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150709/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150709/CERN.csv.gz
#   inflating: nasdaq100/2015/20150709/CA.csv.gz
#   inflating: nasdaq100/2015/20150709/CELG.csv.gz
#   inflating: nasdaq100/2015/20150709/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150709/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150709/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150709/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150709/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150709/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150709/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150709/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150709/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150709/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150709/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150709/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150709/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150709/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150709/ADP.csv.gz
#   inflating: nasdaq100/2015/20150709/ADI.csv.gz
#   inflating: nasdaq100/2015/20150709/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150709/AAL.csv.gz
#    creating: nasdaq100/2015/20150708/
#   inflating: nasdaq100/2015/20150708/XLNX.csv.gz
#   inflating: nasdaq100/2015/20150708/SRCL.csv.gz
#   inflating: nasdaq100/2015/20150708/YHOO.csv.gz
#   inflating: nasdaq100/2015/20150708/WYNN.csv.gz
#   inflating: nasdaq100/2015/20150708/WFM.csv.gz
#   inflating: nasdaq100/2015/20150708/WBA.csv.gz
#   inflating: nasdaq100/2015/20150708/WDC.csv.gz
#   inflating: nasdaq100/2015/20150708/VRTX.csv.gz
#   inflating: nasdaq100/2015/20150708/VRSK.csv.gz
#   inflating: nasdaq100/2015/20150708/VOD.csv.gz
#   inflating: nasdaq100/2015/20150708/TSLA.csv.gz
#   inflating: nasdaq100/2015/20150708/TXN.csv.gz
#   inflating: nasdaq100/2015/20150708/VIAB.csv.gz
#   inflating: nasdaq100/2015/20150708/VIP.csv.gz
#   inflating: nasdaq100/2015/20150708/TSCO.csv.gz
#   inflating: nasdaq100/2015/20150708/STX.csv.gz
#   inflating: nasdaq100/2015/20150708/SYMC.csv.gz
#   inflating: nasdaq100/2015/20150708/TRIP.csv.gz
#   inflating: nasdaq100/2015/20150708/SPLS.csv.gz
#   inflating: nasdaq100/2015/20150708/SIRI.csv.gz
#   inflating: nasdaq100/2015/20150708/SNDK.csv.gz
#   inflating: nasdaq100/2015/20150708/ROST.csv.gz
#   inflating: nasdaq100/2015/20150708/SBUX.csv.gz
#   inflating: nasdaq100/2015/20150708/SIAL.csv.gz
#   inflating: nasdaq100/2015/20150708/SBAC.csv.gz
#   inflating: nasdaq100/2015/20150708/REGN.csv.gz
#   inflating: nasdaq100/2015/20150708/QVCA.csv.gz
#   inflating: nasdaq100/2015/20150708/QCOM.csv.gz
#   inflating: nasdaq100/2015/20150708/PCLN.csv.gz
#   inflating: nasdaq100/2015/20150708/ORLY.csv.gz
#   inflating: nasdaq100/2015/20150708/PCAR.csv.gz
#   inflating: nasdaq100/2015/20150708/PAYX.csv.gz
#   inflating: nasdaq100/2015/20150708/NFLX.csv.gz
#   inflating: nasdaq100/2015/20150708/NTAP.csv.gz
#   inflating: nasdaq100/2015/20150708/NXPI.csv.gz
#   inflating: nasdaq100/2015/20150708/NVDA.csv.gz
#   inflating: nasdaq100/2015/20150708/MYL.csv.gz
#   inflating: nasdaq100/2015/20150708/MU.csv.gz
#   inflating: nasdaq100/2015/20150708/MSFT.csv.gz
#   inflating: nasdaq100/2015/20150708/MNST.csv.gz
#   inflating: nasdaq100/2015/20150708/LMCK.csv.gz
#   inflating: nasdaq100/2015/20150708/MAT.csv.gz
#   inflating: nasdaq100/2015/20150708/MDLZ.csv.gz
#   inflating: nasdaq100/2015/20150708/MAR.csv.gz
#   inflating: nasdaq100/2015/20150708/LRCX.csv.gz
#   inflating: nasdaq100/2015/20150708/LVNTA.csv.gz
#   inflating: nasdaq100/2015/20150708/LMCA.csv.gz
#   inflating: nasdaq100/2015/20150708/LLTC.csv.gz
#   inflating: nasdaq100/2015/20150708/LILAK.csv.gz
#   inflating: nasdaq100/2015/20150708/LILA.csv.gz
#   inflating: nasdaq100/2015/20150708/LBTYK.csv.gz
#   inflating: nasdaq100/2015/20150708/LBTYA.csv.gz
#   inflating: nasdaq100/2015/20150708/KLAC.csv.gz
#   inflating: nasdaq100/2015/20150708/KHC.csv.gz
#   inflating: nasdaq100/2015/20150708/INTC.csv.gz
#   inflating: nasdaq100/2015/20150708/INTU.csv.gz
#   inflating: nasdaq100/2015/20150708/ISRG.csv.gz
#   inflating: nasdaq100/2015/20150708/HSIC.csv.gz
#   inflating: nasdaq100/2015/20150708/ILMN.csv.gz
#   inflating: nasdaq100/2015/20150708/GRMN.csv.gz
#   inflating: nasdaq100/2015/20150708/GOOGL.csv.gz
#   inflating: nasdaq100/2015/20150708/GMCR.csv.gz
#   inflating: nasdaq100/2015/20150708/GILD.csv.gz
#   inflating: nasdaq100/2015/20150708/GOOG.csv.gz
#   inflating: nasdaq100/2015/20150708/FB.csv.gz
#   inflating: nasdaq100/2015/20150708/FOX.csv.gz
#   inflating: nasdaq100/2015/20150708/FOXA.csv.gz
#   inflating: nasdaq100/2015/20150708/FISV.csv.gz
#   inflating: nasdaq100/2015/20150708/EXPD.csv.gz
#   inflating: nasdaq100/2015/20150708/FAST.csv.gz
#   inflating: nasdaq100/2015/20150708/ESRX.csv.gz
#   inflating: nasdaq100/2015/20150708/DTV.csv.gz
#   inflating: nasdaq100/2015/20150708/EA.csv.gz
#   inflating: nasdaq100/2015/20150708/EBAY.csv.gz
#   inflating: nasdaq100/2015/20150708/DISCK.csv.gz
#   inflating: nasdaq100/2015/20150708/DLTR.csv.gz
#   inflating: nasdaq100/2015/20150708/CHTR.csv.gz
#   inflating: nasdaq100/2015/20150708/DISCA.csv.gz
#   inflating: nasdaq100/2015/20150708/DISH.csv.gz
#   inflating: nasdaq100/2015/20150708/CTXS.csv.gz
#   inflating: nasdaq100/2015/20150708/CTSH.csv.gz
#   inflating: nasdaq100/2015/20150708/CTRX.csv.gz
#   inflating: nasdaq100/2015/20150708/COST.csv.gz
#   inflating: nasdaq100/2015/20150708/CMCSA.csv.gz
#   inflating: nasdaq100/2015/20150708/CSCO.csv.gz
#   inflating: nasdaq100/2015/20150708/CERN.csv.gz
#   inflating: nasdaq100/2015/20150708/CMCSK.csv.gz
#   inflating: nasdaq100/2015/20150708/CHRW.csv.gz
#   inflating: nasdaq100/2015/20150708/CHKP.csv.gz
#   inflating: nasdaq100/2015/20150708/CELG.csv.gz
#   inflating: nasdaq100/2015/20150708/CA.csv.gz
#   inflating: nasdaq100/2015/20150708/BRCM.csv.gz
#   inflating: nasdaq100/2015/20150708/BIDU.csv.gz
#   inflating: nasdaq100/2015/20150708/BIIB.csv.gz
#   inflating: nasdaq100/2015/20150708/AMGN.csv.gz
#   inflating: nasdaq100/2015/20150708/AMZN.csv.gz
#   inflating: nasdaq100/2015/20150708/ATVI.csv.gz
#   inflating: nasdaq100/2015/20150708/AVGO.csv.gz
#   inflating: nasdaq100/2015/20150708/BBBY.csv.gz
#   inflating: nasdaq100/2015/20150708/AMAT.csv.gz
#   inflating: nasdaq100/2015/20150708/ALXN.csv.gz
#   inflating: nasdaq100/2015/20150708/ALTR.csv.gz
#   inflating: nasdaq100/2015/20150708/AKAM.csv.gz
#   inflating: nasdaq100/2015/20150708/ADSK.csv.gz
#   inflating: nasdaq100/2015/20150708/ADP.csv.gz
#   inflating: nasdaq100/2015/20150708/ADBE.csv.gz
#   inflating: nasdaq100/2015/20150708/AAPL.csv.gz
#   inflating: nasdaq100/2015/20150708/ADI.csv.gz
#   inflating: nasdaq100/2015/20150708/AAL.csv.gz

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import talib

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/quant_finance/ml_book/Machine-Learning-for-Algorithmic-Trading-Second-Edition/')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline

from pathlib import Path
from tqdm import tqdm

import numpy as np
import pandas as pd

from scipy.stats import spearmanr

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
sns.set_style('whitegrid')
idx = pd.IndexSlice
deciles = np.arange(.1, 1, .1)

# %% [markdown]
# ## Algoseek Trade & Quote Minute Bar Data

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The Quote fields are based on changes to the NBBO ([National Best Bid Offer](https://www.investopedia.com/terms/n/nbbo.asp)) from the top-of-book price and size from
# each of the exchanges.
#
# The enhanced Trade & Quote bar fields include the following fields:
# - **Field**: Name of Field.
# - **Q / T**: Field based on Quotes or Trades
# - **Type**: Field format
# - **No Value**: Value of field when there is no value or data.
#   - Note: “Never” means field should always have a value EXCEPT for the first bar of the day.
# - **Description**: Description of the field.
#
# See [docs](https://us-equity-market-data-docs.s3.amazonaws.com/algoseek.US.Equity.TAQ.Minute.Bars.pdf) for additional detail.

# %% [markdown]
# | id  | Field                   | Q/T  | Type                          |  No Value | Description                                                                                                                                                                                                         |
# |:---:|:------------------------|:----:|:------------------------------|:---------:|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 1  | `Date`                   |      | YYYYMMDD                      | Never     | Trade Date                                                                                                                                                                                                          |
# | 2  | `Ticker`                 |      | String                       | Never      | Ticker Symbol                                                                                                                                                                                                       |
# | 3  | `TimeBarStart`           |      | HHMM <br>HHMMSS <br>HHMMSSMMM | Never     | For minute bars: HHMM. <br>For second bars: HHMMSS. <br>Examples<br>- One second bar 130302 is from time greater than 130301 to 130302.<br>- One minute bar 1104 is from time greater than 1103 to 1104. |
# | 4  | `OpenBarTime`            | Q    | HHMMSSMMM                    | Never      | Open Time of the Bar, for example one minute:<br>11:03:00.000                                                                                                                                                       |
# | 5  | `OpenBidPrice`           | Q    | Number                        | Never     | NBBO Bid Price as of bar Open                                                                                                                                                                                       |
# | 6  | `OpenBidSize`            | Q    | Number                        | Never     | Total Size from all Exchanges with<br>OpenBidPrice                                                                                                                                                                  |
# | 7  | `OpenAskPrice`           | Q    | Number                        | Never     | NBBO Ask Price as of bar Open                                                                                                                                                                                       |
# | 8  | `OpenAskSize`            | Q    | Number                        | Never     | Total Size from all Exchange with<br>OpenAskPrice                                                                                                                                                                   |
# | 9  | `FirstTradeTime`         | T    | HHMMSSMMM                     | Blank     | Time of first Trade                                                                                                                                                                                                 |
# | 10 | `FirstTradePrice`        | T    | Number                        | Blank     | Price of first Trade                                                                                                                                                                                                |
# | 11 | `FirstTradeSize`         | T    | Number                        | Blank     | Number of shares of first trade                                                                                                                                                                                     |
# | 12 | `HighBidTime`            | Q    | HHMMSSMMM                     | Never     | Time of highest NBBO Bid Price                                                                                                                                                                                      |
# | 13 | `HighBidPrice`           | Q    | Number                        | Never     | Highest NBBO Bid Price                                                                                                                                                                                              |
# | 14 | `HighBidSize`            | Q    | Number                        | Never     | Total Size from all Exchanges with HighBidPrice                                                                                                                                                                  |
# | 15 | `AskPriceAtHighBidPrice` | Q    | Number                        | Never     | Ask Price at time of Highest Bid Price                                                                                                                                                                              |
# | 16 | `AskSizeAtHighBidPrice`  | Q    | Number                        | Never     | Total Size from all Exchanges with `AskPriceAtHighBidPrice`                                                                                                                                                        |
# | 17 | `HighTradeTime`          | T    | HHMMSSMMM                     | Blank     | Time of Highest Trade                                                                                                                                                                                               |
# | 18 | `HighTradePrice`         | T    | Number                        | Blank     | Price of highest Trade                                                                                                                                                                                              |
# | 19 | `HighTradeSize`          | T    | Number                        | Blank     | Number of shares of highest trade                                                                                                                                                                                   |
# | 20 | `LowBidTime`             | Q    | HHMMSSMMM                     | Never     | Time of lowest Bid                                                                                                                                                                                                  |
# | 21 | `LowBidPrice`            | Q    | Number                        | Never     | Lowest NBBO Bid price of bar.                                                                                                                                                                                       |
# | 22 | `LowBidSize`             | Q    | Number                        | Never     | Total Size from all Exchanges with `LowBidPrice`                                                                                                                                                                   |
# | 23 | `AskPriceAtLowBidPrice`  | Q    | Number                        | Never     | Ask Price at lowest Bid price                                                                                                                                                                                       |
# | 24  | `AskSizeAtLowBidPrice`  | Q    | Number                        | Never     | Total Size from all Exchanges with `AskPriceAtLowBidPrice`                                                                                                                                                                                       |
# | 25  | `LowTradeTime`          | T    | HHMMSSMMM                     | Blank     | Time of lowest Trade                                                                                                                                                                                                                             |
# | 26  | `LowTradePrice`         | T    | Number                        | Blank     | Price of lowest Trade                                                                                                                                                                                                                            |
# | 27  | `LowTradeSize`          | T    | Number                        | Blank     | Number of shares of lowest trade                                                                                                                                                                                                                 |
# | 28  | `CloseBarTime`          | Q    | HHMMSSMMM                     | Never     | Close Time of the Bar, for example one minute: 11:03:59.999                                                                                                                                                                                      |
# | 29  | `CloseBidPrice`         | Q    | Number                        | Never     | NBBO Bid Price at bar Close                                                                                                                                                                                                                      |
# | 30  | `CloseBidSize`          | Q    | Number                        | Never     | Total Size from all Exchange with `CloseBidPrice`                                                                                                                                                                                                |
# | 31  | `CloseAskPrice`         | Q    | Number                        | Never     | NBBO Ask Price at bar Close                                                                                                                                                                                                                      |
# | 32  | `CloseAskSize`          | Q    | Number                        | Never     | Total Size from all Exchange with `CloseAskPrice`                                                                                                                                                                                                |
# | 33  | `LastTradeTime`         | T    | HHMMSSMMM                     | Blank     | Time of last Trade                                                                                                                                                                                                                               |
# | 34  | `LastTradePrice`        | T    | Number                        | Blank     | Price of last Trade                                                                                                                                                                                                                              |
# | 35  | `LastTradeSize`         | T    | Number                        | Blank     | Number of shares of last trade                                                                                                                                                                                                                   |
# | 36  | `MinSpread`             | Q    | Number                        | Never     | Minimum Bid-Ask spread size. This may be 0 if the market was crossed during the bar.<br/>If negative spread due to back quote, make it 0.                                                                                                            |
# | 37  | `MaxSpread`             | Q    | Number                        | Never     | Maximum Bid-Ask spread in bar                                                                                                                                                                                                                    |
# | 38  | `CancelSize`            | T    | Number                        | 0         | Total shares canceled. Default=blank                                                                                                                                                                                                             |
# | 39  | `VolumeWeightPrice`     | T    | Number                        | Blank     | Trade Volume weighted average price <br>Sum((`Trade1Shares`*`Price`)+(`Trade2Shares`*`Price`)+…)/`TotalShares`. <br>Note: Blank if no trades.                                                                                                        |
# | 40  | `NBBOQuoteCount`        | Q    | Number                        | 0         | Number of Bid and Ask NNBO quotes during bar period.                                                                                                                                                                                             |
# | 41  | `TradeAtBid`            | Q,T  | Number                        | 0         | Sum of trade volume that occurred at or below the bid (a trade reported/printed late can be below current bid).                                                                                                                                  |
# | 42  | `TradeAtBidMid`         | Q,T  | Number                        | 0         | Sum of trade volume that occurred between the bid and the mid-point:<br/>(Trade Price > NBBO Bid ) & (Trade Price < NBBO Mid )                                                                                                                       |
# | 43  | `TradeAtMid`            | Q,T  | Number                        | 0         | Sum of trade volume that occurred at mid.<br/>TradePrice = NBBO MidPoint                                                                                                                                                                             |
# | 44  | `TradeAtMidAsk`         | Q,T  | Number                        | 0         | Sum of ask volume that occurred between the mid and ask:<br/>(Trade Price > NBBO Mid) & (Trade Price < NBBO Ask)                                                                                                                                     |
# | 45  | `TradeAtAsk`            | Q,T  | Number                        | 0         | Sum of trade volume that occurred at or above the Ask.                                                                                                                                                                                           |
# | 46  | `TradeAtCrossOrLocked`  | Q,T  | Number                        | 0         | Sum of trade volume for bar when national best bid/offer is locked or crossed. <br>Locked is Bid = Ask <br>Crossed is Bid > Ask                                                                                                                  |
# | 47  | `Volume`                | T    | Number                        | 0         | Total number of shares traded                                                                                                                                                                                                                    |
# | 48  | `TotalTrades`           | T    | Number                        | 0         | Total number of trades                                                                                                                                                                                                                           |
# | 49  | `FinraVolume`           | T    | Number                        | 0         | Number of shares traded that are reported by FINRA. <br/>Trades reported by FINRA are from broker-dealer internalization, dark pools, Over-The-Counter, etc. <br/>FINRA trades represent volume that is hidden or not public available to trade.         |
# | 50  | `UptickVolume`          | T    | Integer                       | 0         | Total number of shares traded with upticks during bar.<br/>An uptick = ( trade price > last trade price )                                                                                                                                                                                                                               |
# | 51  | `DowntickVolume`        | T    | Integer                       | 0         | Total number of shares traded with downticks during bar.<br/>A downtick = ( trade price < last trade price )                                                                                                                                                                                                                            |
# | 52  | `RepeatUptickVolume`    | T    | Integer                       | 0         | Total number of shares where trade price is the same (repeated) and last price change was up during bar. <br/>Repeat uptick = ( trade price == last trade price ) & (last tick direction == up )                                                                                                                                         |
# | 53  | `RepeatDowntickVolume`  | T    | Integer                       | 0         | Total number of shares where trade price is the same (repeated) and last price change was down during bar. <br/>Repeat downtick = ( trade price == last trade price ) & (last tick direction == down )                                                                                                                                   |
# | 54  | `UnknownVolume`         | T    | Integer                       | 0         | When the first trade of the day takes place, the tick direction is “unknown” as there is no previous Trade to compare it to.<br/>This field is the volume of the first trade after 4am and acts as an initiation value for the tick volume directions.<br/>In future this bar will be renamed to `UnkownTickDirectionVolume` .  |

# %% [markdown]
# ### Notes
#
# **Empty Fields**
#
# An empty field has no value and is “Blank” , for example FirstTradeTime and there are no trades during the bar period.
# The field `Volume` measuring total number of shares traded in bar will be `0` if there are no Trades (see `No Value` column above for each field).
#
# **No Bid/Ask/Trade OHLC**
#
# During a bar timeframe there may not be a change in the NBBO or an actual Trade.
# For example, there can be a bar with OHLC Bid/Ask but no Trade OHLC.
#
# **Single Event**
#
# For bars with only one trade, one NBBO bid or one NBBO ask then Open/High/Low/Close price,size andtime will be the same.
#
# **`AskPriceAtHighBidPrice`, `AskSizeAtHighBidPrice`, `AskPriceAtLowBidPrice`, `AskSizeAtLowBidPrice` Fields**
#
# To provide consistent Bid/Ask prices at a point in time while showing the low/high Bid/Ask for the bar, AlgoSeek uses the low/high `Bid` and the corresponding `Ask` at that price.
#
# ### FAQ
#
# **Why are Trade Prices often inside the Bid Price to Ask Price range?**
#
# The Low/High Bid/Ask is the low and high NBBO price for the bar range.
# Very often a Trade may not occur at these prices as the price may only last a few seconds or executions are being crossed at mid-point due to hidden order types that execute at mid-point or as price improvement over current `Bid`/`Ask`.
#
# **How to get exchange tradable shares?**
#
# To get the exchange tradable volume in a bar subtract `Volume` from `FinraVolume`.
# - `Volume` is the total number of shares traded.
# - ``FinraVolume`` is the total number of shares traded that are reported as executions by FINRA.
#
# When a trade is done that is off the listed exchanges, it must be reported to FINRA by the brokerage firm or dark pool. Examples include:
# - internal crosses by broker dealer
# - over-the-counter block trades, and
# - dark pool executions.

# %% [markdown]
# ## Data prep

# %% [markdown]
# We use the 'Trade and Quote' dataset - see [documentation](https://www.algoseek.com/old_static/files/documentation/equity_and_etf_etn/AlgoSeek.US.Equity.TradeAndQuotes.OHLC.Bars.1.5.pdf) for details on the definition of the numerous fields.

# %%
tcols = ['openbartime', 
         'firsttradetime',
         'highbidtime', 
         'highasktime', 
         'hightradetime',
         'lowbidtime', 
         'lowasktime', 
         'lowtradetime',
         'closebartime', 
         'lasttradetime']

# %%
drop_cols = ['unknowntickvolume',
             'cancelsize',
             'tradeatcrossorlocked']

# %%
keep = ['firsttradeprice', 
        'hightradeprice', 
        'lowtradeprice', 
        'lasttradeprice', 
        'minspread', 
        'maxspread',
        'volumeweightprice', 
        'nbboquotecount', 
        'tradeatbid', 
        'tradeatbidmid', 
        'tradeatmid', 
        'tradeatmidask', 
        'tradeatask', 
        'volume', 
        'totaltrades', 
        'finravolume', 
        'finravolumeweightprice', 
        'uptickvolume', 
        'downtickvolume', 
        'repeatuptickvolume', 
        'repeatdowntickvolume', 
        'tradetomidvolweight', 
        'tradetomidvolweightrelative']

# %% [markdown]
# We will shorten most of the field names to reduce typing:

# %%
columns = {'volumeweightprice'          : 'price',
           'finravolume'                : 'fvolume',
           'finravolumeweightprice'     : 'fprice',
           'uptickvolume'               : 'up',
           'downtickvolume'             : 'down',
           'repeatuptickvolume'         : 'rup',
           'repeatdowntickvolume'       : 'rdown',
           'firsttradeprice'            : 'first',
           'hightradeprice'             : 'high',
           'lowtradeprice'              : 'low',
           'lasttradeprice'             : 'last',
           'nbboquotecount'             : 'nbbo',
           'totaltrades'                : 'ntrades',
           'openbidprice'               : 'obprice',
           'openbidsize'                : 'obsize',
           'openaskprice'               : 'oaprice',
           'openasksize'                : 'oasize',
           'highbidprice'               : 'hbprice',
           'highbidsize'                : 'hbsize',
           'highaskprice'               : 'haprice',
           'highasksize'                : 'hasize',
           'lowbidprice'                : 'lbprice',
           'lowbidsize'                 : 'lbsize',
           'lowaskprice'                : 'laprice',
           'lowasksize'                 : 'lasize',
           'closebidprice'              : 'cbprice',
           'closebidsize'               : 'cbsize',
           'closeaskprice'              : 'caprice',
           'closeasksize'               : 'casize',
           'firsttradesize'             : 'firstsize',
           'hightradesize'              : 'highsize',
           'lowtradesize'               : 'lowsize',
           'lasttradesize'              : 'lastsize',
           'tradetomidvolweight'        : 'volweight',
           'tradetomidvolweightrelative': 'volweightrel'}

# %% [markdown]
# The Algoseek minute-bar data comes in compressed csv files that contain the data for one symbol and day, organized in three directories for each year (2015-17). The function `extract_and_combine_data` reads the ~80K source files and combines them into a single `hdf5` file for faster access.
#
# >The data is fairly large (>8GB), and if you run into memory constraints, please modify the code to process the data in smaller chunks. One options is to iterate over the three directories containing data for a single year only, and storing each year separately.

# %%
nasdaq_path = Path('/content/nasdaq100')

# %%
def extract_and_combine_data():
    path = nasdaq_path / '1min_taq'
    if not path.exists():
        path.mkdir(parents=True)

    data = []
    # ~80K files to process
    for f in tqdm(list(path.glob('../*/**/*.csv.gz'))):
        data.append(pd.read_csv(f, parse_dates=[['Date', 'TimeBarStart']])
                    .rename(columns=str.lower)
                    .drop(tcols + drop_cols, axis=1)
                    .rename(columns=columns)
                    .set_index('date_timebarstart')
                    .sort_index()
                    .between_time('9:30', '16:00')
                    .set_index('ticker', append=True)
                    .swaplevel()
                    .rename(columns=lambda x: x.replace('tradeat', 'at')))
    data = pd.concat(data).apply(pd.to_numeric, downcast='integer')
    data.index.rename(['ticker', 'date_time'], inplace=True)
    print(data.info(show_counts=True))
    data.to_hdf(nasdaq_path / 'algoseek.h5', 'min_taq')

# %%
extract_and_combine_data()
# Out:
# 100%|██████████| 80194/80194 [22:00<00:00, 60.72it/s]
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31355463 entries, ('TSCO', Timestamp('2016-07-06 09:30:00')) to ('CERN', Timestamp('2015-10-29 16:00:00'))
# Data columns (total 45 columns):
#  #   Column         Non-Null Count     Dtype
# ---  ------         --------------     -----
#  0   obprice        31355451 non-null  float64
#  1   obsize         31355451 non-null  float64
#  2   oaprice        31355457 non-null  float64
#  3   oasize         31355457 non-null  float64
#  4   first          30955838 non-null  float64
#  5   firstsize      30955838 non-null  float64
#  6   hbprice        31355463 non-null  float64
#  7   hbsize         31355463 non-null  int32
#  8   haprice        31355463 non-null  float64
#  9   hasize         31355463 non-null  int32
#  10  high           30955838 non-null  float64
#  11  highsize       30955838 non-null  float64
#  12  lbprice        31355463 non-null  float64
#  13  lbsize         31355463 non-null  int32
#  14  laprice        31355463 non-null  float64
#  15  lasize         31355463 non-null  int32
#  16  low            30955838 non-null  float64
#  17  lowsize        30955838 non-null  float64
#  18  cbprice        31355463 non-null  float64
#  19  cbsize         31355463 non-null  int32
#  20  caprice        31355463 non-null  float64
#  21  casize         31355463 non-null  int32
#  22  last           30955838 non-null  float64
#  23  lastsize       30955838 non-null  float64
#  24  minspread      31354810 non-null  float64
#  25  maxspread      31355327 non-null  float64
#  26  price          30386944 non-null  float64
#  27  nbbo           31355463 non-null  int32
#  28  atbid          31355463 non-null  int32
#  29  atbidmid       31355463 non-null  int32
#  30  atmid          31355463 non-null  int32
#  31  atmidask       31355463 non-null  int32
#  32  atask          31355463 non-null  int32
#  33  volume         31355463 non-null  int32
#  34  ntrades        31355463 non-null  int16
#  35  fvolume        31355463 non-null  int32
#  36  fprice         29561289 non-null  float64
#  37  up             31355463 non-null  int32
#  38  down           31355463 non-null  int32
#  39  rup            31355463 non-null  int32
#  40  rdown          31355463 non-null  int32
#  41  volweight      30386944 non-null  float64
#  42  volweightrel   30386944 non-null  float64
#  43  timeweightbid  31355463 non-null  float64
#  44  timeweightask  31355463 non-null  float64
# dtypes: float64(26), int16(1), int32(18)
# memory usage: 8.4+ GB
# None

# %% [markdown]
# ## Loading Algoseek Data

# %%
ohlcv_cols = ['first', 'high', 'low', 'last', 'price', 'volume']

# %%
data_cols = ohlcv_cols + ['up', 'down', 'rup', 'rdown', 'atask', 'atbid']

# %%
with pd.HDFStore(nasdaq_path / 'algoseek.h5') as store:
    df = store['min_taq'].loc[:, data_cols].sort_index()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-776fbba8aa6a> in <module>
#       1 with pd.HDFStore(nasdaq_path / 'algoseek.h5') as store:
# ----> 2     df = store['min_taq'].loc[:, data_cols].sort_index()
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/pytables.py in __getitem__(self, key)
#     606
#     607     def __getitem__(self, key: str):
# --> 608         return self.get(key)
#     609
#     610     def __setitem__(self, key: str, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/pytables.py in get(self, key)
#     798             if group is None:
#     799                 raise KeyError(f"No object named {key} in the file")
# --> 800             return self._read_group(group)
#     801
#     802     def select(
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/pytables.py in _read_group(self, group)
#    1792         s = self._create_storer(group)
#    1793         s.infer_axes()
# -> 1794         return s.read()
#    1795
#    1796     def _identify_group(self, key: str, append: bool) -> Node:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/pytables.py in read(self, where, columns, start, stop)
#    3202
#    3203         if len(dfs) > 0:
# -> 3204             out = concat(dfs, axis=1)
#    3205             out = out.reindex(columns=items, copy=False)
#    3206             return out
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     525                     # 1-ax to convert BlockManager axis to DataFrame axis
#     526                     obj_labels = obj.axes[1 - ax]
# --> 527                     if not new_labels.equals(obj_labels):
#     528                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     529
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/multi.py in equals(self, other)
#    3506                 return False
#    3507             self_codes = self_codes[~self_mask]
# -> 3508             self_values = self.levels[i]._values.take(self_codes)
#    3509
#    3510             other_codes = other_codes[~other_mask]
#
# KeyboardInterrupt:

# %%
df['date'] = pd.to_datetime(df.index.get_level_values('date_time').date)

# %% [markdown]
# We persist the reduced dataset:

# %%
df.to_hdf('/content/algoseek.h5', 'data')

# %%
df = pd.read_hdf('/content/algoseek.h5', 'data')

# %%
df.info(null_counts=True)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# All of the features above were normalized in a standard fashion
# by subtracting their means, dividing by their standard deviations, and time-averaging over a recent
# interval. In order to obtain a finite state space, features were discretized into bins in multiples of
# standard deviation units

# %% [markdown]
# We will compute feature per ticker or ticker and date:

# %%
by_ticker = df.sort_index().groupby('ticker', group_keys=False)
by_ticker_date = df.sort_index().groupby(['ticker', 'date'])

# %% [markdown]
# Create empty `DataFrame` with original ticker/timestamp index to hold our features:

# %%
data = pd.DataFrame(index=df.index)

# %%
data['date'] = pd.factorize(df['date'], sort=True)[0]

# %%
data['minute'] = pd.to_timedelta(data.index.get_level_values('date_time').time.astype(str))
data.minute = (data.minute.dt.seconds.sub(data.minute.dt.seconds.min()).div(60).astype(int))

# %% [markdown]
# ### Lagged Returns

# %% [markdown]
# We create lagged returns with respect to first and last price per bar for each the past 10 minutes:

# %%
data[f'ret1min'] = df['last'].div(df['first']).sub(1)

# %% [markdown]
# 1-min returns have rather heavy tails:

# %%
sns.kdeplot(data.ret1min.sample(n=100000));

# %%
data.ret1min.describe(percentiles=np.arange(.1, 1, .1)).iloc[1:].apply(lambda x: f'{x:.3%}')

# %%
print(f'Skew: {data.ret1min.skew():.2f} | Kurtosis: {data.ret1min.kurtosis():.2f}')

# %% [markdown]
# Intra-bar price moves with the highest returns:

# %%
data.join(df[['first', 'last']]).nlargest(10, columns=['ret1min'])

# %% [markdown]
# We compute similarly for the remaining periods:

# %%
for t in tqdm(range(2, 11)):
    data[f'ret{t}min'] = df['last'].div(by_ticker_date['first'].shift(t-1)).sub(1)

# %% [markdown]
# ### Forward Returns

# %% [markdown]
# We obtain our 1-min forward return target by shifting the one-period return by one minute into the past (which implies the assumption that we always enter and exit a position at those prices, also ignoring trading cost and potential market impact):

# %%
data['fwd1min'] = (data
                   .sort_index()
                   .groupby(['ticker', 'date'])
                   .ret1min
                   .shift(-1))

# %%
data = data.dropna(subset=['fwd1min'])

# %%
data.info(null_counts=True)

# %% [markdown]
# ### Normalized up/downtick volume

# %%
for f in ['up', 'down', 'rup', 'rdown']:
    data[f] = df.loc[:, f].div(df.volume).replace(np.inf, np.nan)

# %%
data.loc[:, ['rup', 'up', 'rdown', 'down']].describe(deciles)

# %% [markdown]
# ### Balance of Power

# %%
data['BOP'] = (by_ticker.apply(lambda x: talib.BOP(x['first'],
                                                   x.high,
                                                   x.low,
                                                   x['last'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0b1e3bb8eec1> in <module>
# ----> 1 data['BOP'] = (by_ticker.apply(lambda x: talib.BOP(x['first'],
#       2                                                    x.high,
#       3                                                    x.low,
#       4                                                    x['last'])))
#
# NameError: name 'by_ticker' is not defined

# %% [markdown]
# ###  Commodity Channel Index

# %%
data['CCI'] = (by_ticker.apply(lambda x: talib.CCI(x.high,
                                          x.low,
                                          x['last'],
                                          timeperiod=14)))

# %% [markdown]
# ### Money Flow Index

# %%
data['MFI'] = (by_ticker.apply(lambda x: talib.MFI(x.high,
                                          x.low,
                                          x['last'],
                                          x.volume,
                                          timeperiod=14)))

# %%
data[['BOP', 'CCI', 'MFI']].describe(deciles)

# %% [markdown]
# ### Stochastic RSI

# %%
data['STOCHRSI'] = (by_ticker.apply(lambda x: talib.STOCHRSI(x['last'].ffill(),
                                                             timeperiod=14,
                                                             fastk_period=14,
                                                             fastd_period=3,
                                                             fastd_matype=0)[0]))

# %% [markdown]
# ### Stochastic Oscillator

# %%
def compute_stoch(x, fastk_period=14, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0):
    slowk, slowd = talib.STOCH(x.high.ffill(), x.low.ffill(), x['last'].ffill(), 
                               fastk_period=fastk_period,
                               slowk_period=slowk_period,
                               slowk_matype=slowk_matype,
                               slowd_period=slowd_period,
                               slowd_matype=slowd_matype)
    return pd.DataFrame({'slowd': slowd, 
                         'slowk': slowk}, 
                        index=x.index)

# %%
data = data.join(by_ticker.apply(compute_stoch))

# %% [markdown]
# ### Average True Range

# %%
data['NATR'] = by_ticker.apply(lambda x: talib.NATR(x.high.ffill(), 
                                                    x.low.ffill(), 
                                                    x['last'].ffill()))

# %% [markdown]
# ### Transaction Volume by price point

# %%
data['trades_bid_ask'] = df.atask.sub(df.atbid).div(df.volume).replace((np.inf, -np.inf), np.nan)

# %%
del df

# %%
data.info(show_counts=True)

# %% [markdown]
# ### Evaluate features

# %%
features = ['ret1min', 'ret2min', 'ret3min', 'ret4min', 'ret5min', 
            'ret6min', 'ret7min', 'ret8min', 'ret9min', 'ret10min',
            'rup', 'up', 'down', 'rdown', 'BOP', 'CCI', 'MFI', 'STOCHRSI', 
            'slowk', 'slowd', 'trades_bid_ask']

# %%
sample = data.sample(n=100000)

# %%
fig, axes = plt.subplots(nrows=3, ncols=7, figsize=(30, 12))
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.distplot(sample[feature], ax=axes[i])
    axes[i].set_title(feature.upper())
    
sns.despine()
fig.tight_layout()

# %%
sns.pairplot(sample, y_vars=['fwd1min'], x_vars=features);

# %%
corr = sample.loc[:, features].corr()
sns.clustermap(corr, cmap = sns.diverging_palette(20, 230, as_cmap=True),
              center=0, vmin=-.25);

# %%
ic = {}
for feature in tqdm(features):
    df = data[['fwd1min', feature]].dropna()
    by_day = df.groupby(df.index.get_level_values('date_time').date) # calc per min is very time-consuming
    ic[feature] = by_day.apply(lambda x: spearmanr(x.fwd1min, x[feature])[0]).mean()
ic = pd.Series(ic)

# %%
ic.sort_values()

# %%
title = 'Information Coeficient for Intraday Features (1-min forward returns)'
ic.index = ic.index.map(str.upper)
ax = ic.sort_values(ascending=False).plot.bar(figsize=(14, 4), title=title, rot=35)
ax.set_ylabel('Information Coefficient')
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.1%}'.format(y))) 
sns.despine()
plt.tight_layout();

# %% [markdown]
# ### Store results

# %%
data.info(null_counts=True)

# %%
data.drop(['date', 'up', 'down'], axis=1).to_hdf('data/algoseek.h5', 'model_data')
